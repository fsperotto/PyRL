# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

from pyrl.agents.classic.tensorforce import PPOAgent
# from pyrl.agents.survival.tensorforce import SurvivalA2CAgent
from pyrl.environments.survival import SurvivalEnv
from pyrl import Sim, Agent, Env, EnvWrapper, System

from pyrl.environments.tf_grid import TFGridEnv, TFGridEnvGUI

from gymnasium.spaces import Discrete, MultiDiscrete

# %%
#ENVIRONMENT PARAMETERS

num_cols = 50
num_rows = 5
map_size = (num_cols, num_rows)

minor_r = 5
major_r = 50
step_r = -1

horizon = 5000
gamma = 0.95
batch_size = 64
learning_rate = 0.001

epsilon = 0.7

repeat = 1

budgets = np.array([100, 200, 300, 400, 500, 600, 700, 800])

reward_targets = {major_r : [(num_cols - 2, num_rows // 2)],
                  minor_r : [(3*(num_cols - 1) // 5, num_rows // 2), ((num_cols - 1) // 3, num_rows // 2)]}

# %% [markdown]
# ## Test with rendering
#
# In the next cell, we call a single simulation with visual rendering.
#
# Use `skip_visual_test` to enable or disable it.

# %%
skip_visual_test = False

if skip_visual_test:
    
    print("Skipping visual test")
    
else:
    
    env = TFGridEnv(num_rows=num_rows, num_cols=num_cols, 
                  reward_mode="s'", reward_targets=reward_targets, default_reward=-1.0,
                  render_mode="external")

    initial_budget = 100

    agent_PPO = PPOAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=initial_budget,
                        gamma=gamma,
                        memory=1000,
                        learning_rate=learning_rate,
                        )

    sim = Sim([agent_PPO], env, episode_horizon=horizon)
    
    
    gui = TFGridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

    gui.launch(give_first_step=True, start_running=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1244\1013969799.py in <cell line: 3>()
#      13     initial_budget = 100
#      14
# ---> 15     agent_PPO = PPOAgent(env=env,
#      16                         observation_space=env.observation_space,
#      17                         action_space=env.action_space,
#
# c:\users\ayman\desktop\pyrl\src\pyrl\agents\classic\tensorforce\ppo.py in __init__(self, env, observation_space, action_space, batch_size, initial_observation, initial_budget, max_episode_timesteps, network, store_N, use_beta_distribution, memory, update_frequency, learning_rate, multi_step, subsampling_fraction, likelihood_ratio_clipping, gamma, reward_processing, return_processing, advantage_processing, predict_terminal_values, baseline, baseline_optimizer, state_preprocessing, exploration_rate, variable_noise, l2_regularization, entropy_regularization, parallel_interactions, config, saver, summarizer, tracking, recorder, **kwargs)
#      28
#      29         self.initial_observation = initial_observation
# ---> 30         self.agent = TensorforceAgent.create(
#      31                         agent='ppo',
#      32                         environment=env,
#
# c:\users\ayman\desktop\tensorforce\tensorforce\agents\agent.py in create(agent, environment, **kwargs)
#     122                 # Keyword specification
#     123                 agent = tensorforce.agents.agents[agent]
# --> 124                 return Agent.create(agent=agent, environment=environment, **kwargs)
#     125
#     126             else:
#
# c:\users\ayman\desktop\tensorforce\tensorforce\agents\agent.py in create(agent, environment, **kwargs)
#      96
#      97             if isinstance(agent, type) and issubclass(agent, Agent):
# ---> 98                 agent = agent(**kwargs)
#      99                 assert isinstance(agent, Agent)
#     100             else:
#
# c:\users\ayman\desktop\tensorforce\tensorforce\agents\ppo.py in __init__(self, states, actions, max_episode_timesteps, batch_size, network, use_beta_distribution, memory, update_frequency, learning_rate, multi_step, subsampling_fraction, likelihood_ratio_clipping, discount, reward_processing, return_processing, advantage_processing, predict_terminal_values, baseline, baseline_optimizer, state_preprocessing, exploration, variable_noise, l2_regularization, entropy_regularization, parallel_interactions, config, saver, summarizer, tracking, recorder, **kwargs)
#     261             baseline_objective = dict(type='state_value')
#     262
# --> 263         super().__init__(
#     264             # Agent
#     265             states=states, actions=actions, max_episode_timesteps=max_episode_timesteps,
#
# c:\users\ayman\desktop\tensorforce\tensorforce\agents\tensorforce.py in __init__(self, states, actions, update, optimizer, objective, reward_estimation, max_episode_timesteps, policy, memory, baseline, baseline_optimizer, baseline_objective, l2_regularization, entropy_regularization, state_preprocessing, exploration, variable_noise, parallel_interactions, config, saver, summarizer, tracking, recorder, **kwargs)
#     444         )
#     445
# --> 446         self.model = TensorforceModel(
#     447             states=self.states_spec, actions=self.actions_spec,
#     448             max_episode_timesteps=self.max_episode_timesteps,
#
# c:\users\ayman\desktop\tensorforce\tensorforce\core\models\tensorforce.py in __init__(self, states, actions, max_episode_timesteps, policy, memory, update, optimizer, objective, reward_estimation, baseline, baseline_optimizer, baseline_objective, l2_regularization, entropy_regularization, state_preprocessing, exploration, variable_noise, parallel_interactions, config, saver, summarizer, tracking)
#     532                 min_capacity = max(min_capacity, 2 * self.config.buffer_observe)
#     533
# --> 534         self.memory = self.submodule(
#     535             name='memory', module=memory, modules=memory_modules, is_trainable=False,
#     536             values_spec=values_spec, min_capacity=min_capacity
#
# c:\users\ayman\desktop\tensorforce\tensorforce\core\module.py in submodule(self, name, module, modules, default_module, is_trainable, is_saved, **kwargs)
#     508         # Module constructor
#     509         Module._MODULE_STACK.append(module_cls)
# --> 510         module = module_cls(*args, **kwargs)
#     511         popped = Module._MODULE_STACK.pop()
#     512         assert popped is module
#
# c:\users\ayman\desktop\tensorforce\tensorforce\core\memories\queue.py in __init__(self, capacity, device, name, values_spec, min_capacity)
#      51             else:
#      52                 self.capacity = self.min_capacity
# ---> 53         elif capacity < self.min_capacity:
#      54             raise TensorforceError.value(
#      55                 name='memory', argument='capacity', value=capacity,
#
# TypeError: '<' not supported between instances of 'int' and 'NoneType'

# %%
def simulation_started_callback(sim):
    #print("START SIM")
    #print(sim.env.observation_shape)
    #print(sim.env.action_shape)
    #print(sim.env.observation_shape + env.action_shape)
    sim.metrics = dict(
        time = 0,
        exploration = np.zeros(sim.env.observation_shape + sim.env.action_shape),
        budget = np.zeros((sim.episode_horizon,), dtype=int)
    )

def simulation_finished_callback(sim):
    print("END SIM")

def episode_started_callback(sim):
    print("START EPISODE")

def episode_finished_callback(sim):
    print("END EPISODE")
    #pass

def round_started_callback(sim):
    #print("START ROUND")
    pass

def round_finished_callback(sim):
    # print("END ROUND")
    sim.metrics["time"] = sim.metrics["time"] + 1
    state_action_index = tuple(np.concatenate( (sim.agent.get_state(), sim.agent.get_action()) ) )
    v = sim.metrics["exploration"].item(state_action_index)
    sim.metrics["exploration"].itemset(state_action_index, v+1)
    sim.metrics["budget"][sim.t-1] = agent.budget

# %% [markdown]
# ## Massive Tests

# %%
env = TFGridEnv(num_rows=num_rows, num_cols=num_cols, 
              reward_mode="s'", reward_targets=reward_targets, default_reward=-1.0,
              render_mode="human")

# %% [markdown]
# ## Classic PPO $\varepsilon = 0.1$

# %%
ppo_time_mean = np.full(budgets.shape, -1)
ppo_exploration_rate = np.full(budgets.shape, -1)
ppo_alive_rate = np.full(budgets.shape, -1)
ppo_budget_evolutions_mean = np.full(budgets.shape, None)
ppo_budget_evolutions_max = np.full(budgets.shape, None)
ppo_budget_evolutions_min = np.full(budgets.shape, None)
ppo_exploration_map = np.full(budgets.shape, None)

epsilon = 0.1

print("====> Classic PPO with epsilon = ", epsilon)

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = ppoAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)
        
        if ppo_time_mean[i] == -1:
            ppo_time_mean[i] = sim.metrics["time"]
        else:
            ppo_time_mean[i] = ppo_time_mean[i] + (1/j) * (sim.metrics["time"] - ppo_time_mean[i])
        
        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if ppo_exploration_rate[i] == -1:
            ppo_exploration_rate[i] = exploration_rate
        else:
            ppo_exploration_rate[i] = ppo_exploration_rate[i] + (1 / j) * (exploration_rate - ppo_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        ppo_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if ppo_budget_evolutions_mean[i] is None:
            ppo_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            ppo_budget_evolutions_mean[i] = ppo_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - ppo_budget_evolutions_mean[i])

        # budget evolution max
        if ppo_budget_evolutions_max[i] is None:
            ppo_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            ppo_budget_evolutions_max[i] = np.maximum(ppo_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if ppo_budget_evolutions_min[i] is None:
            ppo_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            ppo_budget_evolutions_min[i] = np.minimum(ppo_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if ppo_exploration_map[i] is None:
            ppo_exploration_map[i] = sim.metrics["exploration"]
        else:
            ppo_exploration_map[i] = ppo_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - ppo_exploration_map[i])

        print(f"Time mean : {ppo_time_mean[i]}")
        print(f"Alive rate : {ppo_alive_rate[i]}%")
    print("================================================")


ppo_1_time_mean = ppo_time_mean
ppo_1_exploration_rate = ppo_exploration_rate
ppo_1_alive_rate = ppo_alive_rate
ppo_1_budget_evolutions_mean = ppo_budget_evolutions_mean
ppo_1_budget_evolutions_max = ppo_budget_evolutions_max
ppo_1_budget_evolutions_min = ppo_budget_evolutions_min
ppo_1_exploration_map = ppo_exploration_map
# Out:
# ====> Classic A2C with epsilon =  0.1
# Initial Budget : 100
# Iteration 1:
# Time mean : 100
# Alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# Time mean : 200
# Alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# Time mean : 330
# Alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# Time mean : 406
# Alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# Time mean : 524
# Alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# Time mean : 600
# Alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# Time mean : 700
# Alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# Time mean : 872
# Alive rate : 0%
# ================================================

# %% [markdown]
# ## Classic A2C $\varepsilon = 0.3$

# %%
a2c_time_mean = np.full(budgets.shape, -1)
a2c_exploration_rate = np.full(budgets.shape, -1)
a2c_alive_rate = np.full(budgets.shape, -1)
a2c_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_budget_evolutions_max = np.full(budgets.shape, None)
a2c_budget_evolutions_min = np.full(budgets.shape, None)
a2c_exploration_map = np.full(budgets.shape, None)

exploration_rate = 0.3

print("====> Classic A2C with epsilon = ", epsilon)

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = A2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)

        if a2c_time_mean[i] == -1:
            a2c_time_mean[i] = sim.metrics["time"]
        else:
            a2c_time_mean[i] = a2c_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_time_mean[i])
        
        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_exploration_rate[i] == -1:
            a2c_exploration_rate[i] = exploration_rate
        else:
            a2c_exploration_rate[i] = a2c_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_budget_evolutions_mean[i] is None:
            a2c_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_mean[i] = a2c_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_budget_evolutions_max[i] is None:
            a2c_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_max[i] = np.maximum(a2c_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_budget_evolutions_min[i] is None:
            a2c_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_min[i] = np.minimum(a2c_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_exploration_map[i] is None:
            a2c_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_exploration_map[i] = a2c_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_exploration_map[i])

        print(f"Time mean : {a2c_time_mean[i]}")
        print(f"Alive rate : {a2c_alive_rate[i]}%")
    print("================================================")



a2c_3_time_mean = a2c_time_mean
a2c_3_exploration_rate = a2c_exploration_rate
a2c_3_alive_rate = a2c_alive_rate
a2c_3_budget_evolutions_mean = a2c_budget_evolutions_mean
a2c_3_budget_evolutions_max = a2c_budget_evolutions_max
a2c_3_budget_evolutions_min = a2c_budget_evolutions_min
a2c_3_exploration_map = a2c_exploration_map
# Out:
# ====> Classic A2C with epsilon =  0.1
# Initial Budget : 100
# Iteration 1:
# Time mean : 100
# Alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# Time mean : 200
# Alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# Time mean : 300
# Alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# Time mean : 418
# Alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# Time mean : 500
# Alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# Time mean : 726
# Alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# Time mean : 700
# Alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# Time mean : 800
# Alive rate : 0%
# ================================================

# %% [markdown]
# ## Classic A2C $\varepsilon = 0.5$

# %%
a2c_time_mean = np.full(budgets.shape, -1)
a2c_exploration_rate = np.full(budgets.shape, -1)
a2c_alive_rate = np.full(budgets.shape, -1)
a2c_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_budget_evolutions_max = np.full(budgets.shape, None)
a2c_budget_evolutions_min = np.full(budgets.shape, None)
a2c_exploration_map = np.full(budgets.shape, None)

epsilon = 0.5

print("====> Classic A2C with epsilon = ", epsilon)

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = A2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)
        

        if a2c_time_mean[i] == -1:
            a2c_time_mean[i] = sim.metrics["time"]
        else:
            a2c_time_mean[i] = a2c_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_time_mean[i])
        
        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_exploration_rate[i] == -1:
            a2c_exploration_rate[i] = exploration_rate
        else:
            a2c_exploration_rate[i] = a2c_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_budget_evolutions_mean[i] is None:
            a2c_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_mean[i] = a2c_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_budget_evolutions_max[i] is None:
            a2c_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_max[i] = np.maximum(a2c_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_budget_evolutions_min[i] is None:
            a2c_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_min[i] = np.minimum(a2c_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_exploration_map[i] is None:
            a2c_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_exploration_map[i] = a2c_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_exploration_map[i])

        print(f"Time mean : {a2c_time_mean[i]}")
        print(f"Alive rate : {a2c_alive_rate[i]}%")
    print("================================================")


a2c_5_time_mean = a2c_time_mean
a2c_5_exploration_rate = a2c_exploration_rate
a2c_5_alive_rate = a2c_alive_rate
a2c_5_budget_evolutions_mean = a2c_budget_evolutions_mean
a2c_5_budget_evolutions_max = a2c_budget_evolutions_max
a2c_5_budget_evolutions_min = a2c_budget_evolutions_min
a2c_5_exploration_map = a2c_exploration_map
# Out:
# ====> Classic A2C with epsilon =  0.5
# Initial Budget : 100
# Iteration 1:
# Time mean : 100
# Alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# Time mean : 200
# Alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# Time mean : 300
# Alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# Time mean : 400
# Alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# Time mean : 554
# Alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# Time mean : 600
# Alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# Time mean : 742
# Alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# Time mean : 800
# Alive rate : 0%
# ================================================

# %% [markdown]
# ## Classic A2C greedy

# %%
a2c_time_mean = np.full(budgets.shape, -1)
a2c_exploration_rate = np.full(budgets.shape, -1)
a2c_alive_rate = np.full(budgets.shape, -1)
a2c_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_budget_evolutions_max = np.full(budgets.shape, None)
a2c_budget_evolutions_min = np.full(budgets.shape, None)
a2c_exploration_map = np.full(budgets.shape, None)

epsilon = 0.0

print("====> Classic A2C with epsilon = ", epsilon)

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = A2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)

        if a2c_time_mean[i] == -1:
            a2c_time_mean[i] = sim.metrics["time"]
        else:
            a2c_time_mean[i] = a2c_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_time_mean[i])
        
        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_exploration_rate[i] == -1:
            a2c_exploration_rate[i] = exploration_rate
        else:
            a2c_exploration_rate[i] = a2c_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_budget_evolutions_mean[i] is None:
            a2c_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_mean[i] = a2c_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_budget_evolutions_max[i] is None:
            a2c_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_max[i] = np.maximum(a2c_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_budget_evolutions_min[i] is None:
            a2c_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_min[i] = np.minimum(a2c_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_exploration_map[i] is None:
            a2c_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_exploration_map[i] = a2c_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_exploration_map[i])

        print(f"Time mean : {a2c_time_mean[i]}")
        print(f"Alive rate : {a2c_alive_rate[i]}%")
    print("================================================")


a2c_0_time_mean = a2c_time_mean
a2c_0_exploration_rate = a2c_exploration_rate
a2c_0_alive_rate = a2c_alive_rate
a2c_0_budget_evolutions_mean = a2c_budget_evolutions_mean
a2c_0_budget_evolutions_max = a2c_budget_evolutions_max
a2c_0_budget_evolutions_min = a2c_budget_evolutions_min
a2c_0_exploration_map = a2c_exploration_map
# Out:
# ====> Classic A2C with epsilon =  0.0
# Initial Budget : 100
# Iteration 1:
# Time mean : 100
# Alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# Time mean : 200
# Alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# Time mean : 300
# Alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# Time mean : 400
# Alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# Time mean : 524
# Alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# Time mean : 606
# Alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# Time mean : 700
# Alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# Time mean : 812
# Alive rate : 0%
# ================================================

# %% [markdown]
# ## Classic A2C optimistic

# %%
a2c_time_mean = np.full(budgets.shape, -1)
a2c_exploration_rate = np.full(budgets.shape, -1)
a2c_alive_rate = np.full(budgets.shape, -1)
a2c_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_budget_evolutions_max = np.full(budgets.shape, None)
a2c_budget_evolutions_min = np.full(budgets.shape, None)
a2c_exploration_map = np.full(budgets.shape, None)

epsilon=1.0

print("====> Classic A2C with epsilon = ", epsilon)

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = A2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)
        

        if a2c_time_mean[i] == -1:
            a2c_time_mean[i] = sim.metrics["time"]
        else:
            a2c_time_mean[i] = a2c_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_time_mean[i])
        
        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_exploration_rate[i] == -1:
            a2c_exploration_rate[i] = exploration_rate
        else:
            a2c_exploration_rate[i] = a2c_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_budget_evolutions_mean[i] is None:
            a2c_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_mean[i] = a2c_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_budget_evolutions_max[i] is None:
            a2c_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_max[i] = np.maximum(a2c_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_budget_evolutions_min[i] is None:
            a2c_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_budget_evolutions_min[i] = np.minimum(a2c_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_exploration_map[i] is None:
            a2c_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_exploration_map[i] = a2c_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_exploration_map[i])

        print(f"Time mean : {a2c_time_mean[i]}")
        print(f"Alive rate : {a2c_alive_rate[i]}%")
    print("================================================")



a2c_h_time_mean = a2c_time_mean
a2c_h_exploration_rate = a2c_exploration_rate
a2c_h_alive_rate = a2c_alive_rate
a2c_h_budget_evolutions_mean = a2c_budget_evolutions_mean
a2c_h_budget_evolutions_max = a2c_budget_evolutions_max
a2c_h_budget_evolutions_min = a2c_budget_evolutions_min
a2c_h_exploration_map = a2c_exploration_map
# Out:
# ====> Classic A2C with epsilon =  1.0
# Initial Budget : 100
# Iteration 1:
# Time mean : 100
# Alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# Time mean : 200
# Alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# Time mean : 300
# Alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# Time mean : 400
# Alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# Time mean : 500
# Alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# Time mean : 600
# Alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# Time mean : 724
# Alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# Time mean : 812
# Alive rate : 0%
# ================================================

# %% [markdown]
# ## Survival A2C $w = \{250 - 500\}$

# %%
a2c_survival_time_mean = np.full(budgets.shape, -1)
a2c_survival_exploration_rate = np.full(budgets.shape, -1)
a2c_survival_alive_rate = np.full(budgets.shape, -1)
a2c_survival_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_max = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_min = np.full(budgets.shape, None)
a2c_survival_exploration_map = np.full(budgets.shape, None)

exploration_threshold = 500
survival_threshold = 250

epsilon = 0.4

print("====> Survival A2C with epsilon = ", epsilon, "and exploration threshold and survival thteshold =", (exploration_threshold, survival_threshold))

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        agent = SurvivalA2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        exploration_threshold=exploration_threshold,
                        survival_threshold=survival_threshold,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)

        # gui.launch(give_first_step=True, start_running=True)

        if a2c_survival_time_mean[i] == -1:
            a2c_survival_time_mean[i] = sim.metrics["time"]
        else:
            a2c_survival_time_mean[i] = a2c_survival_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_survival_time_mean[i])

        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_survival_exploration_rate[i] == -1:
            a2c_survival_exploration_rate[i] = exploration_rate
        else:
            a2c_survival_exploration_rate[i] = a2c_survival_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_survival_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_survival_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_survival_budget_evolutions_mean[i] is None:
            a2c_survival_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_mean[i] = a2c_survival_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_survival_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_survival_budget_evolutions_max[i] is None:
            a2c_survival_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_max[i] = np.maximum(a2c_survival_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_survival_budget_evolutions_min[i] is None:
            a2c_survival_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_min[i] = np.minimum(a2c_survival_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_survival_exploration_map[i] is None:
            a2c_survival_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_survival_exploration_map[i] = a2c_survival_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_survival_exploration_map[i])

        #print(f"Time mean : {a2c_survival_time_mean[i]}")
        #print(f"Alive rate : {a2c_survival_alive_rate[i]}%")
        
        print(f"* average survival time : {a2c_survival_time_mean[i]}")
        print(f"* alive rate : {a2c_survival_alive_rate[i]}%")
    print("================================================")
    
a2c_survival_250_time_mean = a2c_survival_time_mean
a2c_survival_250_exploration_rate = a2c_survival_exploration_rate
a2c_survival_250_alive_rate = a2c_survival_alive_rate
a2c_survival_250_budget_evolutions_mean = a2c_survival_budget_evolutions_mean
a2c_survival_250_budget_evolutions_max = a2c_survival_budget_evolutions_max
a2c_survival_250_budget_evolutions_min = a2c_survival_budget_evolutions_min
a2c_survival_250_exploration_map = a2c_survival_exploration_map
# Out:
# ====> Survival A2C with epsilon =  0.4 and exploration threshold and survival thteshold = (500, 250)
# Initial Budget : 100
# Iteration 1:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_12200\4284856815.py in <cell line: 16>()
#
#      34         sim.add_listener('simulation_started', simulation_started_callback)
#
#      35         sim.add_listener('round_finished', round_finished_callback)
#
# ---> 36         sim.run()
#
#      37         # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)
#
#      38
#
#
#
# c:\users\ayman\desktop\pyrl\src\pyrl\_base.py in run(self, steps)
#
#    1285
#
#    1286                 while not self.finished:
#
# -> 1287                    self.step()
#
#    1288
#
#    1289
#
#
#
# c:\users\ayman\desktop\pyrl\src\pyrl\_base.py in step(self)
#
#    1203                self._evoke_listeners('round_started')
#
#    1204
#
# -> 1205                action = self.agent.choose_action()  # agent policy that uses the observation and info
#
#    1206                observation, reward, terminated, truncated, info = self.env.step(action)
#
#    1207
#
#
#
# c:\users\ayman\desktop\pyrl\src\pyrl\agents\survival\tensorforce\a2c.py in choose_action(self)
#
#      98             self.a = self.agent.act(states=states, deterministic=True)
#
#      99         else:
#
# --> 100             self.a = self.agent.act(state=states, deterministic=False)
#
#     101
#
#     102         return self.a
#
#
#
# TypeError: act() got an unexpected keyword argument 'state'

# %% [markdown]
# ## Survival A2C $w = \{400, 800\}$

# %%
a2c_survival_time_mean = np.full(budgets.shape, -1)
a2c_survival_exploration_rate = np.full(budgets.shape, -1)
a2c_survival_alive_rate = np.full(budgets.shape, -1)
a2c_survival_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_max = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_min = np.full(budgets.shape, None)
a2c_survival_exploration_map = np.full(budgets.shape, None)

exploration_threshold = 800
survival_threshold = 400

print("====> Survival A2C with epsilon = ", epsilon, "and exploration threshold and survival thteshold =", (exploration_threshold, survival_threshold))

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        #print(f"====> Survival QLearning {b} | Try {j + 1}")
        #agent = SurvivalQLearning(env.observation_space, env.action_space, survival_threshold=survival_threshold, budget=b, should_explore=should_explore, discount=gamma)
        agent = SurvivalA2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        exploration_threshold=exploration_threshold,
                        survival_threshold=survival_threshold,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)
        # gui.launch(give_first_step=True, start_running=True)
        
        if a2c_survival_time_mean[i] == -1:
            a2c_survival_time_mean[i] = sim.metrics["time"]
        else:
            a2c_survival_time_mean[i] = a2c_survival_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_survival_time_mean[i])

        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_survival_exploration_rate[i] == -1:
            a2c_survival_exploration_rate[i] = exploration_rate
        else:
            a2c_survival_exploration_rate[i] = a2c_survival_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_survival_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_survival_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_survival_budget_evolutions_mean[i] is None:
            a2c_survival_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_mean[i] = a2c_survival_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_survival_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_survival_budget_evolutions_max[i] is None:
            a2c_survival_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_max[i] = np.maximum(a2c_survival_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_survival_budget_evolutions_min[i] is None:
            a2c_survival_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_min[i] = np.minimum(a2c_survival_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_survival_exploration_map[i] is None:
            a2c_survival_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_survival_exploration_map[i] = a2c_survival_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_survival_exploration_map[i])

        #print(f"Time mean : {a2c_survival_time_mean[i]}")
        #print(f"Alive rate : {a2c_survival_alive_rate[i]}%")
        
        print(f"* average survival time : {a2c_survival_time_mean[i]}")
        print(f"* alive rate : {a2c_survival_alive_rate[i]}%")
    print("================================================")
    
a2c_survival_400_time_mean = a2c_survival_time_mean
a2c_survival_400_exploration_rate = a2c_survival_exploration_rate
a2c_survival_400_alive_rate = a2c_survival_alive_rate
a2c_survival_400_budget_evolutions_mean = a2c_survival_budget_evolutions_mean
a2c_survival_400_budget_evolutions_max = a2c_survival_budget_evolutions_max
a2c_survival_400_budget_evolutions_min = a2c_survival_budget_evolutions_min
a2c_survival_400_exploration_map = a2c_survival_exploration_map
# Out:
# ====> Survival A2C with epsilon =  0.4 and exploration threshold and survival thteshold = (800, 400)
# Initial Budget : 100
# Iteration 1:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_19972\2670747303.py in <cell line: 14>()
#
#      19         #print(f"====> Survival QLearning {b} | Try {j + 1}")
#
#      20         #agent = SurvivalQLearning(env.observation_space, env.action_space, survival_threshold=survival_threshold, budget=b, should_explore=should_explore, discount=gamma)
#
# ---> 21         agent = SurvivalA2CAgent(env=env,
#
#      22                         observation_space=env.observation_space,
#
#      23                         action_space=env.action_space,
#
#
#
# NameError: name 'SurvivalA2CAgent' is not defined

# %% [markdown]
# ## Survival A2C $w=\{600 - 1000\}$

# %%
a2c_survival_time_mean = np.full(budgets.shape, -1)
a2c_survival_exploration_rate = np.full(budgets.shape, -1)
a2c_survival_alive_rate = np.full(budgets.shape, -1)
a2c_survival_budget_evolutions_mean = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_max = np.full(budgets.shape, None)
a2c_survival_budget_evolutions_min = np.full(budgets.shape, None)
a2c_survival_exploration_map = np.full(budgets.shape, None)

exploration_threshold = 1000
survival_threshold = 600

print("====> Survival A2C with epsilon = ", epsilon, "and exploration threshold and survival thteshold =", (exploration_threshold, survival_threshold))

for i, b in enumerate(budgets):
    nb_alive = 0
    print(f"Initial Budget : {b}")
    for j in range(repeat):
        print(f"Iteration {j+1}: ")
        #print(f"====> Survival QLearning {b} | Try {j + 1}")
        #agent = SurvivalQLearning(env.observation_space, env.action_space, survival_threshold=survival_threshold, budget=b, should_explore=should_explore, discount=gamma)
        agent = SurvivalA2CAgent(env=env,
                        observation_space=env.observation_space, 
                        action_space=env.action_space,
                        exploration_threshold=exploration_threshold,
                        survival_threshold=survival_threshold,
                        batch_size=batch_size,
                        exploration_rate=epsilon,
                        initial_budget=b,
                        gamma=gamma,
                        learning_rate=learning_rate,
                        )
        sim = Sim(agent, env, episode_horizon=horizon)
        sim.add_listener('simulation_started', simulation_started_callback)
        sim.add_listener('round_finished', round_finished_callback)
        sim.run()
        # gui = GridEnvGUI(sim, cell_size=25, fps=80, close_on_finish=True)
        # gui.launch(give_first_step=True, start_running=True)

        if a2c_survival_time_mean[i] == -1:
            a2c_survival_time_mean[i] = sim.metrics["time"]
        else:
            a2c_survival_time_mean[i] = a2c_survival_time_mean[i] + (1/j) * (sim.metrics["time"] - a2c_survival_time_mean[i])

        exploration_rate = (np.count_nonzero(sim.metrics["exploration"]) / (env.num_obs_comb * env.num_act_comb)) * 100

        if a2c_survival_exploration_rate[i] == -1:
            a2c_survival_exploration_rate[i] = exploration_rate
        else:
            a2c_survival_exploration_rate[i] = a2c_survival_exploration_rate[i] + (1 / j) * (exploration_rate - a2c_survival_exploration_rate[i])

        if agent.budget > 0:
            nb_alive = nb_alive + 1

        a2c_survival_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if a2c_survival_budget_evolutions_mean[i] is None:
            a2c_survival_budget_evolutions_mean[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_mean[i] = a2c_survival_budget_evolutions_mean[i] + (1 / j) * (sim.metrics["budget"] - a2c_survival_budget_evolutions_mean[i])

        # budget evolution max
        if a2c_survival_budget_evolutions_max[i] is None:
            a2c_survival_budget_evolutions_max[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_max[i] = np.maximum(a2c_survival_budget_evolutions_max[i], sim.metrics["budget"])

        # budget evolution min
        if a2c_survival_budget_evolutions_min[i] is None:
            a2c_survival_budget_evolutions_min[i] = sim.metrics["budget"]
        else:
            a2c_survival_budget_evolutions_min[i] = np.minimum(a2c_survival_budget_evolutions_min[i], sim.metrics["budget"])
        
        # exploration map
        if a2c_survival_exploration_map[i] is None:
            a2c_survival_exploration_map[i] = sim.metrics["exploration"]
        else:
            a2c_survival_exploration_map[i] = a2c_survival_exploration_map[i] + (1 / j) * (sim.metrics["exploration"] - a2c_survival_exploration_map[i])

        #print(f"Time mean : {a2c_survival_time_mean[i]}")
        #print(f"Alive rate : {a2c_survival_alive_rate[i]}%")
        
        print(f"* average survival time : {a2c_survival_time_mean[i]}")
        print(f"* alive rate : {a2c_survival_alive_rate[i]}%")
    print("================================================")

    
a2c_survival_600_time_mean = a2c_survival_time_mean
a2c_survival_600_exploration_rate = a2c_survival_exploration_rate
a2c_survival_600_alive_rate = a2c_survival_alive_rate
a2c_survival_600_budget_evolutions_mean = a2c_survival_budget_evolutions_mean
a2c_survival_600_budget_evolutions_max = a2c_survival_budget_evolutions_max
a2c_survival_600_budget_evolutions_min = a2c_survival_budget_evolutions_min
a2c_survival_600_exploration_map = a2c_survival_exploration_map
# Out:
# Initial Budget : 100
# Iteration 1:
# * average survival time : 100
# * alive rate : 0%
# Iteration 2:
# * average survival time : 100
# * alive rate : 0%
# Iteration 3:
# * average survival time : 100
# * alive rate : 0%
# Iteration 4:
# * average survival time : 100
# * alive rate : 0%
# Iteration 5:
# * average survival time : 100
# * alive rate : 0%
# Iteration 6:
# * average survival time : 100
# * alive rate : 0%
# Iteration 7:
# * average survival time : 100
# * alive rate : 0%
# Iteration 8:
# * average survival time : 100
# * alive rate : 0%
# Iteration 9:
# * average survival time : 100
# * alive rate : 0%
# Iteration 10:
# * average survival time : 100
# * alive rate : 0%
# Iteration 11:
# * average survival time : 100
# * alive rate : 0%
# Iteration 12:
# * average survival time : 100
# * alive rate : 0%
# Iteration 13:
# * average survival time : 100
# * alive rate : 0%
# Iteration 14:
# * average survival time : 100
# * alive rate : 0%
# Iteration 15:
# * average survival time : 104
# * alive rate : 0%
# Iteration 16:
# * average survival time : 103
# * alive rate : 0%
# Iteration 17:
# * average survival time : 102
# * alive rate : 0%
# Iteration 18:
# * average survival time : 101
# * alive rate : 0%
# Iteration 19:
# * average survival time : 100
# * alive rate : 0%
# Iteration 20:
# * average survival time : 100
# * alive rate : 0%
# Iteration 21:
# * average survival time : 103
# * alive rate : 0%
# Iteration 22:
# * average survival time : 102
# * alive rate : 0%
# Iteration 23:
# * average survival time : 101
# * alive rate : 0%
# Iteration 24:
# * average survival time : 103
# * alive rate : 0%
# Iteration 25:
# * average survival time : 102
# * alive rate : 0%
# Iteration 26:
# * average survival time : 101
# * alive rate : 0%
# Iteration 27:
# * average survival time : 100
# * alive rate : 0%
# Iteration 28:
# * average survival time : 100
# * alive rate : 0%
# Iteration 29:
# * average survival time : 102
# * alive rate : 0%
# Iteration 30:
# * average survival time : 101
# * alive rate : 0%
# Iteration 31:
# * average survival time : 100
# * alive rate : 0%
# Iteration 32:
# * average survival time : 100
# * alive rate : 0%
# Iteration 33:
# * average survival time : 100
# * alive rate : 0%
# Iteration 34:
# * average survival time : 100
# * alive rate : 0%
# Iteration 35:
# * average survival time : 100
# * alive rate : 0%
# Iteration 36:
# * average survival time : 100
# * alive rate : 0%
# Iteration 37:
# * average survival time : 101
# * alive rate : 0%
# Iteration 38:
# * average survival time : 100
# * alive rate : 0%
# Iteration 39:
# * average survival time : 100
# * alive rate : 0%
# Iteration 40:
# * average survival time : 101
# * alive rate : 0%
# Iteration 41:
# * average survival time : 100
# * alive rate : 0%
# Iteration 42:
# * average survival time : 100
# * alive rate : 0%
# Iteration 43:
# * average survival time : 100
# * alive rate : 0%
# Iteration 44:
# * average survival time : 100
# * alive rate : 0%
# Iteration 45:
# * average survival time : 100
# * alive rate : 0%
# Iteration 46:
# * average survival time : 100
# * alive rate : 0%
# Iteration 47:
# * average survival time : 100
# * alive rate : 0%
# Iteration 48:
# * average survival time : 100
# * alive rate : 0%
# Iteration 49:
# * average survival time : 100
# * alive rate : 0%
# Iteration 50:
# * average survival time : 100
# * alive rate : 0%
# ================================================
# Initial Budget : 200
# Iteration 1:
# * average survival time : 200
# * alive rate : 0%
# Iteration 2:
# * average survival time : 200
# * alive rate : 0%
# Iteration 3:
# * average survival time : 200
# * alive rate : 0%
# Iteration 4:
# * average survival time : 200
# * alive rate : 0%
# Iteration 5:
# * average survival time : 200
# * alive rate : 0%
# Iteration 6:
# * average survival time : 200
# * alive rate : 0%
# Iteration 7:
# * average survival time : 200
# * alive rate : 0%
# Iteration 8:
# * average survival time : 200
# * alive rate : 0%
# Iteration 9:
# * average survival time : 200
# * alive rate : 0%
# Iteration 10:
# * average survival time : 200
# * alive rate : 0%
# Iteration 11:
# * average survival time : 200
# * alive rate : 0%
# Iteration 12:
# * average survival time : 200
# * alive rate : 0%
# Iteration 13:
# * average survival time : 205
# * alive rate : 0%
# Iteration 14:
# * average survival time : 204
# * alive rate : 0%
# Iteration 15:
# * average survival time : 203
# * alive rate : 0%
# Iteration 16:
# * average survival time : 202
# * alive rate : 0%
# Iteration 17:
# * average survival time : 201
# * alive rate : 0%
# Iteration 18:
# * average survival time : 200
# * alive rate : 0%
# Iteration 19:
# * average survival time : 200
# * alive rate : 0%
# Iteration 20:
# * average survival time : 200
# * alive rate : 0%
# Iteration 21:
# * average survival time : 200
# * alive rate : 0%
# Iteration 22:
# * average survival time : 200
# * alive rate : 0%
# Iteration 23:
# * average survival time : 200
# * alive rate : 0%
# Iteration 24:
# * average survival time : 200
# * alive rate : 0%
# Iteration 25:
# * average survival time : 200
# * alive rate : 0%
# Iteration 26:
# * average survival time : 200
# * alive rate : 0%
# Iteration 27:
# * average survival time : 200
# * alive rate : 0%
# Iteration 28:
# * average survival time : 202
# * alive rate : 0%
# Iteration 29:
# * average survival time : 201
# * alive rate : 0%
# Iteration 30:
# * average survival time : 200
# * alive rate : 0%
# Iteration 31:
# * average survival time : 200
# * alive rate : 0%
# Iteration 32:
# * average survival time : 200
# * alive rate : 0%
# Iteration 33:
# * average survival time : 200
# * alive rate : 0%
# Iteration 34:
# * average survival time : 200
# * alive rate : 0%
# Iteration 35:
# * average survival time : 201
# * alive rate : 0%
# Iteration 36:
# * average survival time : 200
# * alive rate : 0%
# Iteration 37:
# * average survival time : 200
# * alive rate : 0%
# Iteration 38:
# * average survival time : 200
# * alive rate : 0%
# Iteration 39:
# * average survival time : 200
# * alive rate : 0%
# Iteration 40:
# * average survival time : 200
# * alive rate : 0%
# Iteration 41:
# * average survival time : 200
# * alive rate : 0%
# Iteration 42:
# * average survival time : 201
# * alive rate : 0%
# Iteration 43:
# * average survival time : 200
# * alive rate : 0%
# Iteration 44:
# * average survival time : 200
# * alive rate : 0%
# Iteration 45:
# * average survival time : 200
# * alive rate : 0%
# Iteration 46:
# * average survival time : 200
# * alive rate : 0%
# Iteration 47:
# * average survival time : 200
# * alive rate : 0%
# Iteration 48:
# * average survival time : 200
# * alive rate : 0%
# Iteration 49:
# * average survival time : 200
# * alive rate : 0%
# Iteration 50:
# * average survival time : 200
# * alive rate : 0%
# ================================================
# Initial Budget : 300
# Iteration 1:
# * average survival time : 300
# * alive rate : 0%
# Iteration 2:
# * average survival time : 300
# * alive rate : 0%
# Iteration 3:
# * average survival time : 714
# * alive rate : 0%
# Iteration 4:
# * average survival time : 576
# * alive rate : 0%
# Iteration 5:
# * average survival time : 507
# * alive rate : 0%
# Iteration 6:
# * average survival time : 465
# * alive rate : 0%
# Iteration 7:
# * average survival time : 437
# * alive rate : 0%
# Iteration 8:
# * average survival time : 417
# * alive rate : 0%
# Iteration 9:
# * average survival time : 402
# * alive rate : 0%
# Iteration 10:
# * average survival time : 390
# * alive rate : 0%
# Iteration 11:
# * average survival time : 381
# * alive rate : 0%
# Iteration 12:
# * average survival time : 373
# * alive rate : 0%
# Iteration 13:
# * average survival time : 366
# * alive rate : 0%
# Iteration 14:
# * average survival time : 361
# * alive rate : 0%
# Iteration 15:
# * average survival time : 356
# * alive rate : 0%
# Iteration 16:
# * average survival time : 352
# * alive rate : 0%
# Iteration 17:
# * average survival time : 348
# * alive rate : 0%
# Iteration 18:
# * average survival time : 345
# * alive rate : 0%
# Iteration 19:
# * average survival time : 342
# * alive rate : 0%
# Iteration 20:
# * average survival time : 339
# * alive rate : 0%
# Iteration 21:
# * average survival time : 337
# * alive rate : 0%
# Iteration 22:
# * average survival time : 335
# * alive rate : 0%
# Iteration 23:
# * average survival time : 333
# * alive rate : 0%
# Iteration 24:
# * average survival time : 331
# * alive rate : 0%
# Iteration 25:
# * average survival time : 329
# * alive rate : 0%
# Iteration 26:
# * average survival time : 327
# * alive rate : 0%
# Iteration 27:
# * average survival time : 325
# * alive rate : 0%
# Iteration 28:
# * average survival time : 324
# * alive rate : 0%
# Iteration 29:
# * average survival time : 323
# * alive rate : 0%
# Iteration 30:
# * average survival time : 322
# * alive rate : 0%
# Iteration 31:
# * average survival time : 321
# * alive rate : 0%
# Iteration 32:
# * average survival time : 320
# * alive rate : 0%
# Iteration 33:
# * average survival time : 319
# * alive rate : 0%
# Iteration 34:
# * average survival time : 340
# * alive rate : 0%
# Iteration 35:
# * average survival time : 339
# * alive rate : 0%
# Iteration 36:
# * average survival time : 337
# * alive rate : 0%
# Iteration 37:
# * average survival time : 335
# * alive rate : 0%
# Iteration 38:
# * average survival time : 335
# * alive rate : 0%
# Iteration 39:
# * average survival time : 334
# * alive rate : 0%
# Iteration 40:
# * average survival time : 333
# * alive rate : 0%
# Iteration 41:
# * average survival time : 332
# * alive rate : 0%
# Iteration 42:
# * average survival time : 331
# * alive rate : 0%
# Iteration 43:
# * average survival time : 330
# * alive rate : 0%
# Iteration 44:
# * average survival time : 329
# * alive rate : 0%
# Iteration 45:
# * average survival time : 328
# * alive rate : 0%
# Iteration 46:
# * average survival time : 331
# * alive rate : 0%
# Iteration 47:
# * average survival time : 330
# * alive rate : 0%
# Iteration 48:
# * average survival time : 329
# * alive rate : 0%
# Iteration 49:
# * average survival time : 339
# * alive rate : 0%
# Iteration 50:
# * average survival time : 338
# * alive rate : 0%
# ================================================
# Initial Budget : 400
# Iteration 1:
# * average survival time : 400
# * alive rate : 0%
# Iteration 2:
# * average survival time : 400
# * alive rate : 0%
# Iteration 3:
# * average survival time : 568
# * alive rate : 0%
# Iteration 4:
# * average survival time : 601
# * alive rate : 0%
# Iteration 5:
# * average survival time : 550
# * alive rate : 0%
# Iteration 6:
# * average survival time : 520
# * alive rate : 0%
# Iteration 7:
# * average survival time : 500
# * alive rate : 0%
# Iteration 8:
# * average survival time : 485
# * alive rate : 0%
# Iteration 9:
# * average survival time : 571
# * alive rate : 0%
# Iteration 10:
# * average survival time : 552
# * alive rate : 0%
# Iteration 11:
# * average survival time : 536
# * alive rate : 0%
# Iteration 12:
# * average survival time : 523
# * alive rate : 0%
# Iteration 13:
# * average survival time : 515
# * alive rate : 0%
# Iteration 14:
# * average survival time : 506
# * alive rate : 0%
# Iteration 15:
# * average survival time : 498
# * alive rate : 0%
# Iteration 16:
# * average survival time : 491
# * alive rate : 0%
# Iteration 17:
# * average survival time : 485
# * alive rate : 0%
# Iteration 18:
# * average survival time : 480
# * alive rate : 0%
# Iteration 19:
# * average survival time : 475
# * alive rate : 0%
# Iteration 20:
# * average survival time : 471
# * alive rate : 0%
# Iteration 21:
# * average survival time : 467
# * alive rate : 0%
# Iteration 22:
# * average survival time : 463
# * alive rate : 0%
# Iteration 23:
# * average survival time : 460
# * alive rate : 0%
# Iteration 24:
# * average survival time : 460
# * alive rate : 0%
# Iteration 25:
# * average survival time : 457
# * alive rate : 0%
# Iteration 26:
# * average survival time : 454
# * alive rate : 0%
# Iteration 27:
# * average survival time : 451
# * alive rate : 0%
# Iteration 28:
# * average survival time : 480
# * alive rate : 0%
# Iteration 29:
# * average survival time : 478
# * alive rate : 0%
# Iteration 30:
# * average survival time : 475
# * alive rate : 0%
# Iteration 31:
# * average survival time : 472
# * alive rate : 0%
# Iteration 32:
# * average survival time : 469
# * alive rate : 0%
# Iteration 33:
# * average survival time : 466
# * alive rate : 0%
# Iteration 34:
# * average survival time : 464
# * alive rate : 0%
# Iteration 35:
# * average survival time : 462
# * alive rate : 0%
# Iteration 36:
# * average survival time : 460
# * alive rate : 0%
# Iteration 37:
# * average survival time : 458
# * alive rate : 0%
# Iteration 38:
# * average survival time : 456
# * alive rate : 0%
# Iteration 39:
# * average survival time : 454
# * alive rate : 0%
# Iteration 40:
# * average survival time : 469
# * alive rate : 0%
# Iteration 41:
# * average survival time : 467
# * alive rate : 0%
# Iteration 42:
# * average survival time : 465
# * alive rate : 0%
# Iteration 43:
# * average survival time : 463
# * alive rate : 0%
# Iteration 44:
# * average survival time : 461
# * alive rate : 0%
# Iteration 45:
# * average survival time : 466
# * alive rate : 0%
# Iteration 46:
# * average survival time : 464
# * alive rate : 0%
# Iteration 47:
# * average survival time : 462
# * alive rate : 0%
# Iteration 48:
# * average survival time : 460
# * alive rate : 0%
# Iteration 49:
# * average survival time : 458
# * alive rate : 0%
# Iteration 50:
# * average survival time : 464
# * alive rate : 0%
# ================================================
# Initial Budget : 500
# Iteration 1:
# * average survival time : 512
# * alive rate : 0%
# Iteration 2:
# * average survival time : 518
# * alive rate : 0%
# Iteration 3:
# * average survival time : 509
# * alive rate : 0%
# Iteration 4:
# * average survival time : 506
# * alive rate : 0%
# Iteration 5:
# * average survival time : 515
# * alive rate : 0%
# Iteration 6:
# * average survival time : 512
# * alive rate : 0%
# Iteration 7:
# * average survival time : 527
# * alive rate : 0%
# Iteration 8:
# * average survival time : 526
# * alive rate : 0%
# Iteration 9:
# * average survival time : 523
# * alive rate : 0%
# Iteration 10:
# * average survival time : 520
# * alive rate : 0%
# Iteration 11:
# * average survival time : 518
# * alive rate : 0%
# Iteration 12:
# * average survival time : 516
# * alive rate : 0%
# Iteration 13:
# * average survival time : 524
# * alive rate : 0%
# Iteration 14:
# * average survival time : 530
# * alive rate : 0%
# Iteration 15:
# * average survival time : 527
# * alive rate : 0%
# Iteration 16:
# * average survival time : 526
# * alive rate : 0%
# Iteration 17:
# * average survival time : 528
# * alive rate : 0%
# Iteration 18:
# * average survival time : 526
# * alive rate : 0%
# Iteration 19:
# * average survival time : 524
# * alive rate : 0%
# Iteration 20:
# * average survival time : 522
# * alive rate : 0%
# Iteration 21:
# * average survival time : 520
# * alive rate : 0%
# Iteration 22:
# * average survival time : 519
# * alive rate : 0%
# Iteration 23:
# * average survival time : 518
# * alive rate : 0%
# Iteration 24:
# * average survival time : 517
# * alive rate : 0%
# Iteration 25:
# * average survival time : 518
# * alive rate : 0%
# Iteration 26:
# * average survival time : 517
# * alive rate : 0%
# Iteration 27:
# * average survival time : 516
# * alive rate : 0%
# Iteration 28:
# * average survival time : 515
# * alive rate : 0%
# Iteration 29:
# * average survival time : 514
# * alive rate : 0%
# Iteration 30:
# * average survival time : 515
# * alive rate : 0%
# Iteration 31:
# * average survival time : 514
# * alive rate : 0%
# Iteration 32:
# * average survival time : 530
# * alive rate : 0%
# Iteration 33:
# * average survival time : 529
# * alive rate : 0%
# Iteration 34:
# * average survival time : 534
# * alive rate : 0%
# Iteration 35:
# * average survival time : 533
# * alive rate : 0%
# Iteration 36:
# * average survival time : 532
# * alive rate : 0%
# Iteration 37:
# * average survival time : 531
# * alive rate : 0%
# Iteration 38:
# * average survival time : 530
# * alive rate : 0%
# Iteration 39:
# * average survival time : 529
# * alive rate : 0%
# Iteration 40:
# * average survival time : 528
# * alive rate : 0%
# Iteration 41:
# * average survival time : 528
# * alive rate : 0%
# Iteration 42:
# * average survival time : 527
# * alive rate : 0%
# Iteration 43:
# * average survival time : 526
# * alive rate : 0%
# Iteration 44:
# * average survival time : 525
# * alive rate : 0%
# Iteration 45:
# * average survival time : 524
# * alive rate : 0%
# Iteration 46:
# * average survival time : 523
# * alive rate : 0%
# Iteration 47:
# * average survival time : 522
# * alive rate : 0%
# Iteration 48:
# * average survival time : 521
# * alive rate : 0%
# Iteration 49:
# * average survival time : 520
# * alive rate : 0%
# Iteration 50:
# * average survival time : 519
# * alive rate : 0%
# ================================================
# Initial Budget : 600
# Iteration 1:
# * average survival time : 600
# * alive rate : 0%
# Iteration 2:
# * average survival time : 1128
# * alive rate : 0%
# Iteration 3:
# * average survival time : 1099
# * alive rate : 0%
# Iteration 4:
# * average survival time : 949
# * alive rate : 0%
# Iteration 5:
# * average survival time : 861
# * alive rate : 0%
# Iteration 6:
# * average survival time : 810
# * alive rate : 0%
# Iteration 7:
# * average survival time : 881
# * alive rate : 0%
# Iteration 8:
# * average survival time : 840
# * alive rate : 0%
# Iteration 9:
# * average survival time : 810
# * alive rate : 0%
# Iteration 10:
# * average survival time : 786
# * alive rate : 0%
# Iteration 11:
# * average survival time : 876
# * alive rate : 0%
# Iteration 12:
# * average survival time : 850
# * alive rate : 0%
# Iteration 13:
# * average survival time : 854
# * alive rate : 0%
# Iteration 14:
# * average survival time : 834
# * alive rate : 0%
# Iteration 15:
# * average survival time : 817
# * alive rate : 0%
# Iteration 16:
# * average survival time : 802
# * alive rate : 0%
# Iteration 17:
# * average survival time : 799
# * alive rate : 0%
# Iteration 18:
# * average survival time : 824
# * alive rate : 0%
# Iteration 19:
# * average survival time : 840
# * alive rate : 0%
# Iteration 20:
# * average survival time : 827
# * alive rate : 0%
# Iteration 21:
# * average survival time : 815
# * alive rate : 0%
# Iteration 22:
# * average survival time : 805
# * alive rate : 0%
# Iteration 23:
# * average survival time : 819
# * alive rate : 0%
# Iteration 24:
# * average survival time : 809
# * alive rate : 0%
# Iteration 25:
# * average survival time : 800
# * alive rate : 0%
# Iteration 26:
# * average survival time : 792
# * alive rate : 0%
# Iteration 27:
# * average survival time : 784
# * alive rate : 0%
# Iteration 28:
# * average survival time : 777
# * alive rate : 0%
# Iteration 29:
# * average survival time : 781
# * alive rate : 0%
# Iteration 30:
# * average survival time : 825
# * alive rate : 0%
# Iteration 31:
# * average survival time : 817
# * alive rate : 0%
# Iteration 32:
# * average survival time : 810
# * alive rate : 0%
# Iteration 33:
# * average survival time : 803
# * alive rate : 0%
# Iteration 34:
# * average survival time : 796
# * alive rate : 0%
# Iteration 35:
# * average survival time : 790
# * alive rate : 0%
# Iteration 36:
# * average survival time : 784
# * alive rate : 0%
# Iteration 37:
# * average survival time : 778
# * alive rate : 0%
# Iteration 38:
# * average survival time : 773
# * alive rate : 0%
# Iteration 39:
# * average survival time : 768
# * alive rate : 0%
# Iteration 40:
# * average survival time : 764
# * alive rate : 0%
# Iteration 41:
# * average survival time : 759
# * alive rate : 0%
# Iteration 42:
# * average survival time : 755
# * alive rate : 0%
# Iteration 43:
# * average survival time : 751
# * alive rate : 0%
# Iteration 44:
# * average survival time : 747
# * alive rate : 0%
# Iteration 45:
# * average survival time : 743
# * alive rate : 0%
# Iteration 46:
# * average survival time : 747
# * alive rate : 0%
# Iteration 47:
# * average survival time : 743
# * alive rate : 0%
# Iteration 48:
# * average survival time : 744
# * alive rate : 0%
# Iteration 49:
# * average survival time : 741
# * alive rate : 0%
# Iteration 50:
# * average survival time : 738
# * alive rate : 0%
# ================================================
# Initial Budget : 700
# Iteration 1:
# * average survival time : 700
# * alive rate : 0%
# Iteration 2:
# * average survival time : 706
# * alive rate : 0%
# Iteration 3:
# * average survival time : 805
# * alive rate : 0%
# Iteration 4:
# * average survival time : 778
# * alive rate : 0%
# Iteration 5:
# * average survival time : 796
# * alive rate : 0%
# Iteration 6:
# * average survival time : 868
# * alive rate : 0%
# Iteration 7:
# * average survival time : 850
# * alive rate : 0%
# Iteration 8:
# * average survival time : 828
# * alive rate : 0%
# Iteration 9:
# * average survival time : 870
# * alive rate : 0%
# Iteration 10:
# * average survival time : 852
# * alive rate : 0%
# Iteration 11:
# * average survival time : 836
# * alive rate : 0%
# Iteration 12:
# * average survival time : 834
# * alive rate : 0%
# Iteration 13:
# * average survival time : 826
# * alive rate : 0%
# Iteration 14:
# * average survival time : 817
# * alive rate : 0%
# Iteration 15:
# * average survival time : 808
# * alive rate : 0%
# Iteration 16:
# * average survival time : 801
# * alive rate : 0%
# Iteration 17:
# * average survival time : 794
# * alive rate : 0%
# Iteration 18:
# * average survival time : 789
# * alive rate : 0%
# Iteration 19:
# * average survival time : 784
# * alive rate : 0%
# Iteration 20:
# * average survival time : 782
# * alive rate : 0%
# Iteration 21:
# * average survival time : 802
# * alive rate : 0%
# Iteration 22:
# * average survival time : 797
# * alive rate : 0%
# Iteration 23:
# * average survival time : 792
# * alive rate : 0%
# Iteration 24:
# * average survival time : 820
# * alive rate : 0%
# Iteration 25:
# * average survival time : 815
# * alive rate : 0%
# Iteration 26:
# * average survival time : 810
# * alive rate : 0%
# Iteration 27:
# * average survival time : 805
# * alive rate : 0%
# Iteration 28:
# * average survival time : 801
# * alive rate : 0%
# Iteration 29:
# * average survival time : 814
# * alive rate : 0%
# Iteration 30:
# * average survival time : 810
# * alive rate : 0%
# Iteration 31:
# * average survival time : 806
# * alive rate : 0%
# Iteration 32:
# * average survival time : 803
# * alive rate : 0%
# Iteration 33:
# * average survival time : 799
# * alive rate : 0%
# Iteration 34:
# * average survival time : 796
# * alive rate : 0%
# Iteration 35:
# * average survival time : 793
# * alive rate : 0%
# Iteration 36:
# * average survival time : 790
# * alive rate : 0%
# Iteration 37:
# * average survival time : 788
# * alive rate : 0%
# Iteration 38:
# * average survival time : 803
# * alive rate : 0%
# Iteration 39:
# * average survival time : 822
# * alive rate : 0%
# Iteration 40:
# * average survival time : 819
# * alive rate : 0%
# Iteration 41:
# * average survival time : 816
# * alive rate : 0%
# Iteration 42:
# * average survival time : 817
# * alive rate : 0%
# Iteration 43:
# * average survival time : 814
# * alive rate : 0%
# Iteration 44:
# * average survival time : 811
# * alive rate : 0%
# Iteration 45:
# * average survival time : 808
# * alive rate : 0%
# Iteration 46:
# * average survival time : 805
# * alive rate : 0%
# Iteration 47:
# * average survival time : 806
# * alive rate : 0%
# Iteration 48:
# * average survival time : 804
# * alive rate : 0%
# Iteration 49:
# * average survival time : 803
# * alive rate : 0%
# Iteration 50:
# * average survival time : 801
# * alive rate : 0%
# ================================================
# Initial Budget : 800
# Iteration 1:
# * average survival time : 812
# * alive rate : 0%
# Iteration 2:
# * average survival time : 818
# * alive rate : 0%
# Iteration 3:
# * average survival time : 1092
# * alive rate : 0%
# Iteration 4:
# * average survival time : 994
# * alive rate : 0%
# Iteration 5:
# * average survival time : 1010
# * alive rate : 0%
# Iteration 6:
# * average survival time : 970
# * alive rate : 0%
# Iteration 7:
# * average survival time : 968
# * alive rate : 0%
# Iteration 8:
# * average survival time : 949
# * alive rate : 0%
# Iteration 9:
# * average survival time : 930
# * alive rate : 0%
# Iteration 10:
# * average survival time : 915
# * alive rate : 0%
# Iteration 11:
# * average survival time : 926
# * alive rate : 0%
# Iteration 12:
# * average survival time : 914
# * alive rate : 0%
# Iteration 13:
# * average survival time : 904
# * alive rate : 0%
# Iteration 14:
# * average survival time : 908
# * alive rate : 0%
# Iteration 15:
# * average survival time : 1022
# * alive rate : 0%
# Iteration 16:
# * average survival time : 1056
# * alive rate : 0%
# Iteration 17:
# * average survival time : 1104
# * alive rate : 0%
# Iteration 18:
# * average survival time : 1122
# * alive rate : 0%
# Iteration 19:
# * average survival time : 1104
# * alive rate : 0%
# Iteration 20:
# * average survival time : 1091
# * alive rate : 0%
# Iteration 21:
# * average survival time : 1076
# * alive rate : 0%
# Iteration 22:
# * average survival time : 1076
# * alive rate : 0%
# Iteration 23:
# * average survival time : 1064
# * alive rate : 0%
# Iteration 24:
# * average survival time : 1052
# * alive rate : 0%
# Iteration 25:
# * average survival time : 1041
# * alive rate : 0%
# Iteration 26:
# * average survival time : 1031
# * alive rate : 0%
# Iteration 27:
# * average survival time : 1022
# * alive rate : 0%
# Iteration 28:
# * average survival time : 1020
# * alive rate : 0%
# Iteration 29:
# * average survival time : 1056
# * alive rate : 0%
# Iteration 30:
# * average survival time : 1048
# * alive rate : 0%
# Iteration 31:
# * average survival time : 1046
# * alive rate : 0%
# Iteration 32:
# * average survival time : 1045
# * alive rate : 0%
# Iteration 33:
# * average survival time : 1050
# * alive rate : 0%
# Iteration 34:
# * average survival time : 1042
# * alive rate : 0%
# Iteration 35:
# * average survival time : 1034
# * alive rate : 0%
# Iteration 36:
# * average survival time : 1027
# * alive rate : 0%
# Iteration 37:
# * average survival time : 1020
# * alive rate : 0%
# Iteration 38:
# * average survival time : 1014
# * alive rate : 0%
# Iteration 39:
# * average survival time : 1008
# * alive rate : 0%
# Iteration 40:
# * average survival time : 1002
# * alive rate : 0%
# Iteration 41:
# * average survival time : 1007
# * alive rate : 0%
# Iteration 42:
# * average survival time : 1001
# * alive rate : 0%
# Iteration 43:
# * average survival time : 1030
# * alive rate : 0%
# Iteration 44:
# * average survival time : 1037
# * alive rate : 0%
# Iteration 45:
# * average survival time : 1036
# * alive rate : 0%
# Iteration 46:
# * average survival time : 1030
# * alive rate : 0%
# Iteration 47:
# * average survival time : 1027
# * alive rate : 0%
# Iteration 48:
# * average survival time : 1036
# * alive rate : 0%
# Iteration 49:
# * average survival time : 1031
# * alive rate : 0%
# Iteration 50:
# * average survival time : 1028
# * alive rate : 0%
# ================================================

# %% [markdown]
# ## Results

# %% [markdown]
# ### Survival time

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(budgets, a2c_5_time_mean, label=f"Classic A2C, $\\varepsilon=0.5$", color='b', marker='^', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_3_time_mean, label=f"Classic A2C, $\\varepsilon=0.3$", color='b', marker='o', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_1_time_mean, label=f"Classic A2C, $\\varepsilon=0.1$", color='b', marker='v', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_0_time_mean, label=f"Classic A2C, greedy, $q_0=0$", color='r', ls='--', marker='*', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_h_time_mean, label=f"Classic A2C, optimistic, $q_0=200$", color='r', ls='--', marker='d', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_250_time_mean, label="Survival A2C, $w = \\{250, 500\\}$", color='g', ls='-', marker='s', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_400_time_mean, label="Survival A2C, $w = \\{400, 800\\}$", color='g', ls='-', marker='X', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_survival_600_time_mean, label="Survival A2C, $w = \\{600, 1000\\}$", color='g', ls='-', marker='D', markerfacecolor='w', markersize=7)
plt.xlabel("Initial budget")
plt.ylabel("Average survival time")
plt.legend()
plt.grid()
plt.title(f"Average survival time in function of initial budget with horizon {horizon} \n repeated {repeat} times for map of size {map_size}")  #and survival threshold [{survival_threshold}-{exploration_threshold}] 
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_19972\1666528258.py in <cell line: 7>()
#
#       5 plt.plot(budgets, a2c_0_time_mean, label=f"Classic A2C, greedy, $q_0=0$", color='r', ls='--', marker='*', markerfacecolor='w', markersize=10)
#
#       6 plt.plot(budgets, a2c_h_time_mean, label=f"Classic A2C, optimistic, $q_0=200$", color='r', ls='--', marker='d', markerfacecolor='w', markersize=8)
#
# ----> 7 plt.plot(budgets, a2c_survival_250_time_mean, label="Survival A2C, $w = \\{250, 500\\}$", color='g', ls='-', marker='s', markerfacecolor='w', markersize=8)
#
#       8 plt.plot(budgets, a2c_survival_400_time_mean, label="Survival A2C, $w = \\{400, 800\\}$", color='g', ls='-', marker='X', markerfacecolor='w', markersize=10)
#
#       9 plt.plot(budgets, a2c_survival_600_time_mean, label="Survival A2C, $w = \\{600, 1000\\}$", color='g', ls='-', marker='D', markerfacecolor='w', markersize=7)
#
#
#
# NameError: name 'a2c_survival_250_time_mean' is not defined

# %% [markdown]
# ### Alive rate

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(budgets, a2c_5_alive_rate, label=f"Classic A2C, $\\varepsilon=0.5$", color='b', marker='^', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_3_alive_rate, label=f"Classic A2C, $\\varepsilon=0.3$", color='b', marker='o', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_1_alive_rate, label=f"Classic A2C, $\\varepsilon=0.1$", color='b', marker='v', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_0_alive_rate, label=f"Classic A2C, greedy, $q_0=0$", color='r', ls='--', marker='*', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_h_alive_rate, label=f"Classic A2C, optimistic, $q_0=200$", color='r', ls='--', marker='d', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_250_alive_rate, label="Survival A2C, $w = \\{250, 500\\}$", color='g', ls='-', marker='s', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_400_alive_rate, label="Survival A2C, $w = \\{400, 800\\}$", color='g', ls='-', marker='X', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_survival_600_alive_rate, label="Survival A2C, $w = \\{600, 1000\\}$", color='g', ls='-', marker='D', markerfacecolor='w', markersize=7)
plt.xlabel("Initial budget")
plt.ylabel("Alive rate (%)")
plt.legend()
plt.grid()
plt.title(f"Alive rate in function of initial budget with horizon {horizon} \n repeated {repeat} times for map of size {map_size}")
plt.show()

# %% [markdown]
# ### Exploration rate

# %%
fig = plt.figure(figsize=(12, 8))
#plt.plot(budgets, cde_exploration_rate, label="CDELearning")
plt.plot(budgets, a2c_5_exploration_rate, label=f"Classic A2C, $\\varepsilon=0.5$", color='b', marker='^', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_3_exploration_rate, label=f"Classic A2C, $\\varepsilon=0.3$", color='b', marker='o', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_1_exploration_rate, label=f"Classic A2C, $\\varepsilon=0.1$", color='b', marker='v', markerfacecolor='w', markersize=8, ls=':')
plt.plot(budgets, a2c_0_exploration_rate, label=f"Classic A2C, greedy, $q_0=0$", color='r', ls='--', marker='*', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_h_exploration_rate, label=f"Classic A2C, optimistic, $q_0=200$", color='r', ls='--', marker='d', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_250_exploration_rate, label="Survival A2C, $w = \\{250, 500\\}$", color='g', ls='-', marker='s', markerfacecolor='w', markersize=8)
plt.plot(budgets, a2c_survival_400_exploration_rate, label="Survival A2C, $w = \\{400, 800\\}$", color='g', ls='-', marker='X', markerfacecolor='w', markersize=10)
plt.plot(budgets, a2c_survival_600_exploration_rate, label="Survival A2C, $w = \\{600, 1000\\}$", color='g', ls='-', marker='D', markerfacecolor='w', markersize=7)
plt.xlabel("Initial budget")
plt.ylabel("Exploration rate (%)")
plt.legend()
plt.grid()
plt.title(f"Exploration rate in function of initial budget with horizon {horizon} \n repeated {repeat} times for map of size {map_size}")
plt.show()

# %% [markdown]
# ### Budget evolution

# %%
print("Available budgets :")
print(budgets)

#plt.rcParams["figure.figsize"] = (10,10)

with_bounds = False

show_only = [300, 400, 500]
colors = ['r', 'g', 'b']
# Out:
# Available budgets :
# [100 200 300 400 500 600 700 800]

# %%
t = np.arange(horizon)

fig = plt.figure(figsize=(12, 8))

n=0
for i, evo in enumerate(a2c_1_budget_evolutions_mean):
    if len(show_only) == 0 or budgets[i] in show_only:
        lines = plt.plot(t, evo, label=f"Q-Learning, $\\varepsilon=0.1$, $b_0=${budgets[i]}", ls='-', color=colors[n])
        n += 1
        if with_bounds:
            plt.fill_between(t, a2c_1_budget_evolutions_min[i], a2c_1__budget_evolutions_max[i], color=lines[0].get_color(), alpha=0.15)

n=0
for i, evo in enumerate(a2c_0_budget_evolutions_mean):
    if len(show_only) == 0 or budgets[i] in show_only:
        lines = plt.plot(t, evo, label=f"Q-Learning, greedy, $b_0=${budgets[i]})", ls=':', color=colors[n])
        n += 1
        if with_bounds:
            plt.fill_between(t, a2c_0_budget_evolutions_min[i], a2c_0_budget_evolutions_max[i], color=lines[0].get_color(), alpha=0.15)
            
n=0
for i, evo in enumerate(a2c_survival_400_budget_evolutions_mean):
    if len(show_only) == 0 or budgets[i] in show_only:
        lines = plt.plot(t, evo, label=f"STQ, $w={{400, 800}}$, $b_0=${budgets[i]})", ls='--', color=colors[n])
        n += 1
        if with_bounds:
            plt.fill_between(t, a2c_survival_400_budget_evolutions_min[i], a2c_survival_400_budget_evolutions_max[i], color=lines[0].get_color(), alpha=0.15)

#plt.yscale('symlog')

#plt.plot(t, np.full((horizon,), survival_threshold), color="magenta", label=f"Survival threshold {survival_threshold}", ls="-.")
#plt.plot(t, 4.5 * t, color="lawngreen", ls="--", label=f"Budget optimal minor")
#plt.plot(t, 49.5 * t, color="turquoise", ls="--", label=f"Budget optimal major")
plt.xlabel("Time")
plt.ylabel("Budget")
plt.legend()
plt.grid()
plt.title(f"Budget evolution in function of time with horizon {horizon} \n repeated {repeat} times for map of size {map_size}")
plt.show()

# %%
from pyrl.agents.classic import A2CAgent
from pyrl.agents.survival import SurvivalA2CAgent
import gymnasium as gym
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

from tensorforce.agents import Agent
from tensorforce.environments import Environment
from pyrl.environments import CustomEnvironment
from tensorforce.execution import Runner

from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from tensorforce.agents import Agent as TFAgent
from tensorforce.core.networks import AutoNetwork

# %%
map_size = (50, 5)
horizon = 5000
points = 6
repeat = 3
survival_threshold = 250
exploration_threshold = 500
gamma = 0.99 # discount factor
initial_budgets = np.linspace(100, horizon, points, dtype=int)

batch_size = 32
exploration_rate = 0.9
learning_rate = 0.001
update_frequency = 1.0

# %%
env = Environment.create(
    environment=CustomEnvironment(render_mode="human", size=map_size),
    max_episode_timesteps=horizon
)

survival_dqn_time_mean = np.full(initial_budgets.shape, -1)
survival_dqn_exploration_rate = np.full(initial_budgets.shape, -1)
survival_dqn_alive_rate = np.full(initial_budgets.shape, -1)
survival_dqn_budget_evolutions = list()

survival_dqn_budget_evolutions_mean = np.full(initial_budgets.shape, None)
survival_dqn_budget_evolutions_max = np.full(initial_budgets.shape, None)
survival_dqn_budget_evolutions_min = np.full(initial_budgets.shape, None)


observation_space = env.states
action_space = env.actions()

for i, b in enumerate(initial_budgets):
    nb_alive = 0
    for j in range(repeat):
        print(f"====> Survival A2C {b} | Try {j + 1}")
        states = env.reset()
        
        agent = SurvivalA2CAgent(environment=env,
                         initial_observation=states,
                         batch_size=batch_size,
                         initial_budget=b,
                         horizon=horizon,
                         exploration=exploration_rate,
                         discount=gamma,
                         update_frequency=update_frequency,
                         learning_rate=learning_rate,
                        )
        
        agent.reset(states)
        exploration_matrix = np.zeros((env.observation_space.n, env.action_space.n))
        budget_evolution = np.zeros((horizon,), dtype=int)
        
        for t in count():
            actions = agent.act(states=states)
            states, terminated, reward= env.execute(actions=actions)
            done = terminated or t >= horizon or agent.b <= 0
            exploration_matrix[int(states), int(actions)] = exploration_matrix[int(states), int(actions)] + 1
            agent.observe(states, reward, terminated=terminated)            
            env.render()
            
            budget_evolution[t-1] = agent.b

            if done:
                print("t = ", t)
                if survival_dqn_time_mean[i] == -1:
                    survival_dqn_time_mean[i] = t
                else:
                    survival_dqn_time_mean[i] = survival_dqn_time_mean[i] + (1/(j+1)) * (t - survival_dqn_time_mean[i])
                break
        
        
        exploration_rate = (np.count_nonzero(exploration_matrix) / (env.observation_space.n * env.action_space.n)) * 100

        if survival_dqn_exploration_rate[i] == -1:
            survival_dqn_exploration_rate[i] = exploration_rate
        else:
            survival_dqn_exploration_rate[i] = survival_dqn_exploration_rate[i] + (1 / (j+1)) * (exploration_rate - survival_dqn_exploration_rate[i])

        if agent.b > 0:
            nb_alive = nb_alive + 1

        survival_dqn_alive_rate[i] = nb_alive / (j+1) * 100

        # budget evolution mean
        if survival_dqn_budget_evolutions_mean[i] is None:
            survival_dqn_budget_evolutions_mean[i] = budget_evolution
        else:
            survival_dqn_budget_evolutions_mean[i] = survival_dqn_budget_evolutions_mean[i] + (1 / (j+1)) * (budget_evolution - survival_dqn_budget_evolutions_mean[i])

        # budget evolution max
        if survival_dqn_budget_evolutions_max[i] is None:
            survival_dqn_budget_evolutions_max[i] = budget_evolution
        else:
            survival_dqn_budget_evolutions_max[i] = np.maximum(survival_dqn_budget_evolutions_max[i], budget_evolution)

        # budget evolution min
        if survival_dqn_budget_evolutions_min[i] is None:
            survival_dqn_budget_evolutions_min[i] = budget_evolution
        else:
            survival_dqn_budget_evolutions_min[i] = np.minimum(survival_dqn_budget_evolutions_min[i], budget_evolution)
        
        print(f"Time mean : {survival_dqn_time_mean[i]}")
        print(f"Alive rate : {survival_dqn_alive_rate[i]}%")
        print(f"Exploration rate: {survival_dqn_exploration_rate[i]}%")
# Out:
# ====> Survival A2C 100 | Try 1
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 6%
# ====> Survival A2C 100 | Try 2
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 5%
# ====> Survival A2C 100 | Try 3
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 4%
# ====> Survival A2C 1080 | Try 1
# t =  1122
# Time mean : 1122
# Alive rate : 0%
# Exploration rate: 43%
# ====> Survival A2C 1080 | Try 2
# t =  1122
# Time mean : 1122
# Alive rate : 0%
# Exploration rate: 47%
# ====> Survival A2C 1080 | Try 3
# t =  1080
# Time mean : 1108
# Alive rate : 0%
# Exploration rate: 37%
# ====> Survival A2C 2060 | Try 1
# t =  2066
# Time mean : 2066
# Alive rate : 0%
# Exploration rate: 44%
# ====> Survival A2C 2060 | Try 2
# t =  2312
# Time mean : 2189
# Alive rate : 0%
# Exploration rate: 52%
# ====> Survival A2C 2060 | Try 3
# t =  2138
# Time mean : 2172
# Alive rate : 0%
# Exploration rate: 48%
# ====> Survival A2C 3040 | Try 1
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 86%
# ====> Survival A2C 3040 | Try 2
# t =  3610
# Time mean : 4304
# Alive rate : 50%
# Exploration rate: 83%
# ====> Survival A2C 3040 | Try 3
# t =  3106
# Time mean : 3904
# Alive rate : 33%
# Exploration rate: 69%
# ====> Survival A2C 4020 | Try 1
# t =  4938
# Time mean : 4938
# Alive rate : 0%
# Exploration rate: 82%
# ====> Survival A2C 4020 | Try 2
# t =  4999
# Time mean : 4968
# Alive rate : 50%
# Exploration rate: 82%
# ====> Survival A2C 4020 | Try 3
# t =  4308
# Time mean : 4748
# Alive rate : 33%
# Exploration rate: 77%
# ====> Survival A2C 5000 | Try 1
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 74%
# ====> Survival A2C 5000 | Try 2
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 78%
# ====> Survival A2C 5000 | Try 3
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 68%

# %%
env = Environment.create(
    environment=CustomEnvironment(render_mode="human", size=map_size),
    max_episode_timesteps=horizon,
)

dqn_time_mean = np.full(initial_budgets.shape, -1)
dqn_exploration_rate = np.full(initial_budgets.shape, -1)
dqn_alive_rate = np.full(initial_budgets.shape, -1)
dqn_budget_evolutions_mean = np.full(initial_budgets.shape, None)
dqn_budget_evolutions_max = np.full(initial_budgets.shape, None)
dqn_budget_evolutions_min = np.full(initial_budgets.shape, None)


observation_space = env.states
action_space = env.actions()

for i, b in enumerate(initial_budgets):
    nb_alive = 0
    for j in range(repeat):
        print(f"====> Classic A2C {b} | Try {j + 1}")
        states = env.reset()
        
        agent = A2CAgent(environment=env,
                         initial_observation=states,
                         batch_size=batch_size,
                         initial_budget=b,
                         horizon=horizon,
                         exploration=exploration_rate,
                         discount=gamma,
                         update_frequency=update_frequency,
                         learning_rate=learning_rate,
                        )
                         
        agent.reset(states)
        exploration_matrix = np.zeros((env.observation_space.n, env.action_space.n))
        budget_evolution = np.zeros((horizon,), dtype=int)
        
        for t in count():
            actions = agent.act(states=states)
            states, terminated, reward = env.execute(actions=actions)
            done = terminated or t >= horizon or agent.b <= 0
            exploration_matrix[int(states), int(actions)] = exploration_matrix[int(states), int(actions)] + 1
            agent.observe(states, reward, terminated=terminated)
            env.render()
            
            budget_evolution[t-1] = agent.b
            
            if done:
                print("t = ", t)
                if dqn_time_mean[i] == -1:
                    dqn_time_mean[i] = t
                else:
                    dqn_time_mean[i] = dqn_time_mean[i] + (1/(j+1)) * (t - dqn_time_mean[i])
                
                break
        
        exploration_rate = (np.count_nonzero(exploration_matrix) / (env.observation_space.n * env.action_space.n)) * 100

        if dqn_exploration_rate[i] == -1:
            dqn_exploration_rate[i] = exploration_rate
        else:
            dqn_exploration_rate[i] = dqn_exploration_rate[i] + (1/(j+1)) * (exploration_rate - dqn_exploration_rate[i])

        if agent.b > 0:
            nb_alive = nb_alive + 1

        dqn_alive_rate[i] = nb_alive / (j+1) * 100
        
         # budget evolution mean
        if dqn_budget_evolutions_mean[i] is None:
            dqn_budget_evolutions_mean[i] = budget_evolution
        else:
            dqn_budget_evolutions_mean[i] = dqn_budget_evolutions_mean[i] + (1/(j+1)) * (budget_evolution - dqn_budget_evolutions_mean[i])

        # budget evolution max
        if dqn_budget_evolutions_max[i] is None:
            dqn_budget_evolutions_max[i] = budget_evolution
        else:
            dqn_budget_evolutions_max[i] = np.maximum(dqn_budget_evolutions_max[i], budget_evolution)

        # budget evolution min
        if dqn_budget_evolutions_min[i] is None:
            dqn_budget_evolutions_min[i] = budget_evolution
        else:
            dqn_budget_evolutions_min[i] = np.minimum(dqn_budget_evolutions_min[i], budget_evolution)
        

        print(f"Time mean : {dqn_time_mean[i]}")
        print(f"Alive rate : {dqn_alive_rate[i]}%")
        print(f"Exploration rate: {dqn_exploration_rate[i]}%")
# Out:
# ====> Classic A2C 100 | Try 1
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 5%
# ====> Classic A2C 100 | Try 2
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 5%
# ====> Classic A2C 100 | Try 3
# t =  100
# Time mean : 100
# Alive rate : 0%
# Exploration rate: 4%
# ====> Classic A2C 1080 | Try 1
# t =  1599
# Time mean : 1599
# Alive rate : 0%
# Exploration rate: 58%
# ====> Classic A2C 1080 | Try 2
# t =  1104
# Time mean : 1351
# Alive rate : 0%
# Exploration rate: 44%
# ====> Classic A2C 1080 | Try 3
# t =  1104
# Time mean : 1268
# Alive rate : 0%
# Exploration rate: 38%
# ====> Classic A2C 2060 | Try 1
# t =  2114
# Time mean : 2114
# Alive rate : 0%
# Exploration rate: 32%
# ====> Classic A2C 2060 | Try 2
# t =  3590
# Time mean : 2852
# Alive rate : 0%
# Exploration rate: 55%
# ====> Classic A2C 2060 | Try 3
# t =  2126
# Time mean : 2610
# Alive rate : 0%
# Exploration rate: 47%
# ====> Classic A2C 3040 | Try 1
# t =  4729
# Time mean : 4729
# Alive rate : 0%
# Exploration rate: 86%
# ====> Classic A2C 3040 | Try 2
# t =  3088
# Time mean : 3908
# Alive rate : 0%
# Exploration rate: 68%
# ====> Classic A2C 3040 | Try 3
# t =  3184
# Time mean : 3666
# Alive rate : 0%
# Exploration rate: 59%
# ====> Classic A2C 4020 | Try 1
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 86%
# ====> Classic A2C 4020 | Try 2
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 81%
# ====> Classic A2C 4020 | Try 3
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 79%
# ====> Classic A2C 5000 | Try 1
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 84%
# ====> Classic A2C 5000 | Try 2
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 78%
# ====> Classic A2C 5000 | Try 3
# t =  4999
# Time mean : 4999
# Alive rate : 100%
# Exploration rate: 79%

# %% [markdown]
# ## Results

# %% [markdown]
# ### Survival time

# %%
plt.plot(initial_budgets, dqn_time_mean, label="Classic A2C")
plt.plot(initial_budgets, survival_dqn_time_mean, label="Survival A2C")
plt.xlabel("Initial budget")
plt.ylabel("Survival time")
plt.legend()
plt.title(f"Survival time in function of initial budget with horizon {horizon} repeated {repeat} times and survival threshold {survival_threshold} for map of size {map_size}")
plt.show()

# %% [markdown]
# ### Alive rate

# %%
plt.plot(initial_budgets, dqn_alive_rate, label="Classic A2C")
plt.plot(initial_budgets, survival_dqn_alive_rate, label="Survival A2C")
plt.xlabel("Initial budget")
plt.ylabel("Alive rate (%)")
plt.legend()
plt.title(f"Alive rate in function of initial budget with horizon {horizon} repeated {repeat} times and survival threshold {survival_threshold} for map of size {map_size}")
plt.show()

# %% [markdown]
# ### Exploration rate

# %%
plt.plot(initial_budgets, dqn_exploration_rate, label="Classic A2C")
plt.plot(initial_budgets, survival_dqn_exploration_rate, label="Survival A2C")
plt.xlabel("Initial budget")
plt.ylabel("Exploration rate (%)")
plt.legend()
plt.title(f"Exploration rate (state + action) in function of initial budget with horizon {horizon} repeated {repeat} times and survival threshold {survival_threshold} for map of size {map_size}")
plt.show()

# %% [markdown]
# ### Budget evolution

# %%
print("Available budgets :")
print(initial_budgets)
# Out:
# Available budgets :
# [ 100 1080 2060 3040 4020 5000]

# %%
plt.rcParams["figure.figsize"] = (10,10)

with_bounds = False

show_only = []

# %% [markdown]
# #### Classic DQN

# %%
t = np.arange(horizon)

for i, evo in enumerate(dqn_budget_evolutions_mean):
    if len(show_only) > 0 and initial_budgets[i] not in show_only:
        continue
    
    lines = plt.plot(t, evo, label=f"Start with budget {initial_budgets[i]}")

    if with_bounds:
        plt.fill_between(t, dqn_budget_evolutions_min[i], dqn_budget_evolutions_max[i], color=lines[0].get_color(), alpha=0.15)

plt.plot(t, np.full((horizon,), survival_threshold), color="magenta", label=f"Survival threshold {survival_threshold}")
plt.plot(t, 4.5 * t, color="lawngreen", ls="--", label=f"Budget optimal minor")
plt.plot(t, 49.5 * t, color="turquoise", ls="--", label=f"Budget optimal major")
plt.xlabel("Time")
plt.ylabel("Budget")
plt.legend()
plt.grid()
plt.title(f"Budget evolution in function of time with horizon {horizon} \n repeated {repeat} times and survival threshold {survival_threshold} for map of size {map_size}")
plt.show()

# %% [markdown]
# #### Survival DQN

# %%
import matplotlib.colors as mcolors

t = np.arange(horizon)

for i, evo in enumerate(survival_dqn_budget_evolutions_mean):
    if len(show_only) > 0 and initial_budgets[i] not in show_only:
        continue
    
    lines = plt.plot(t, evo, label=f"Start with budget {initial_budgets[i]}")

    if with_bounds:
        plt.fill_between(t, survival_dqn_budget_evolutions_min[i], survival_dqn_budget_evolutions_max[i], color=lines[0].get_color(), alpha=0.15)

plt.plot(t, np.full((horizon,), survival_threshold), color="magenta", label=f"Survival threshold {survival_threshold}")
plt.plot(t, 4.5 * t, color="lawngreen", ls="--", label=f"Budget optimal minor")
plt.plot(t, 49.5 * t, color="turquoise", ls="--", label=f"Budget optimal major")
plt.xlabel("Time")
plt.ylabel("Budget")
plt.legend()
plt.grid()
plt.title(f"Budget evolution in function of time with horizon {horizon} \n repeated {repeat} times and survival threshold {survival_threshold} for map of size {map_size}")
plt.show()
