# %% [markdown]
# # Surviving Triangle
#
# The surviving triangle is a budgeted triangle (i.e. centered then shifted) truncated at zero.
#
# $\begin{align}
# \mathcal{Surv}_{b}\mathcal{Z}\binom{n}{s}
# \ & = \ \mathcal{Budget}_{b}\mathcal{Z}\binom{n}{s} - \mathcal{Budget}_{-b}\mathcal{Z}\binom{n}{s}\\
# \ & = \ \begin{cases}
#   \mathcal{Z}\binom{n}{\frac{n+s-b}{2}} - \mathcal{Z}\binom{n}{\frac{n+s+b}{2}} & \text{if } \frac{n + s \pm b}{2} \in \mathbb{N} \\
#   0 & \text{otherwise}
# \end{cases}
# \end{align}$

# %%
from pyrl.gr import *
from pyrl.utils import printdf

################

max_s = 20
s_arr = range(-max_s,max_s+1)
n_arr = range(-3,max_s+1)

printdf([[trunc_budget_triangle(n, s, 5, 0)    for s in s_arr] for n in n_arr], label_rows=n_arr, label_cols=s_arr, label_axis_cols="s", label_axis_rows="n", title='$0$-Truncated $+5$-Centered Triangle:', transpose=True, reverse=True)
# Out:
# <h3>$0$-Truncated $+5$-Centered Triangle:</h3>
# <style  type="text/css" >
#     #T_a183b_ th.row_heading {
#           border-right: 1px solid black;
#     }    #T_a183b_ th.index_name {
#           border-right: 1px solid black;
#     }    #T_a183b_ td {
#           padding: 2px;
#           margin: 0;
#     }    #T_a183b_ th {
#           padding: 2px;
#           margin: 0;
#     }    #T_a183b_ td.row20 {
#           border-top: 1px dotted grey;
#           border-bottom: 1px dotted grey;
#     }    #T_a183b_ td.col3 {
#           border-left: 1px dotted grey;
#           border-right: 1px dotted grey;
#     }#T_a183b_row0_col0,#T_a183b_row0_col1,#T_a183b_row0_col2,#T_a183b_row0_col3,#T_a183b_row0_col4,#T_a183b_row0_col5,#T_a183b_row0_col6,#T_a183b_row0_col7,#T_a183b_row0_col8,#T_a183b_row0_col9,#T_a183b_row0_col10,#T_a183b_row0_col11,#T_a183b_row0_col12,#T_a183b_row0_col13,#T_a183b_row0_col14,#T_a183b_row0_col15,#T_a183b_row0_col16,#T_a183b_row0_col17,#T_a183b_row0_col19,#T_a183b_row0_col21,#T_a183b_row0_col23,#T_a183b_row1_col0,#T_a183b_row1_col1,#T_a183b_row1_col2,#T_a183b_row1_col3,#T_a183b_row1_col4,#T_a183b_row1_col5,#T_a183b_row1_col6,#T_a183b_row1_col7,#T_a183b_row1_col8,#T_a183b_row1_col9,#T_a183b_row1_col10,#T_a183b_row1_col11,#T_a183b_row1_col12,#T_a183b_row1_col13,#T_a183b_row1_col14,#T_a183b_row1_col15,#T_a183b_row1_col16,#T_a183b_row1_col18,#T_a183b_row1_col20,#T_a183b_row1_col22,#T_a183b_row2_col0,#T_a183b_row2_col1,#T_a183b_row2_col2,#T_a183b_row2_col3,#T_a183b_row2_col4,#T_a183b_row2_col5,#T_a183b_row2_col6,#T_a183b_row2_col7,#T_a183b_row2_col8,#T_a183b_row2_col9,#T_a183b_row2_col10,#T_a183b_row2_col11,#T_a183b_row2_col12,#T_a183b_row2_col13,#T_a183b_row2_col14,#T_a183b_row2_col15,#T_a183b_row2_col17,#T_a183b_row2_col19,#T_a183b_row2_col21,#T_a183b_row2_col23,#T_a183b_row3_col0,#T_a183b_row3_col1,#T_a183b_row3_col2,#T_a183b_row3_col3,#T_a183b_row3_col4,#T_a183b_row3_col5,#T_a183b_row3_col6,#T_a183b_row3_col7,#T_a183b_row3_col8,#T_a183b_row3_col9,#T_a183b_row3_col10,#T_a183b_row3_col11,#T_a183b_row3_col12,#T_a183b_row3_col13,#T_a183b_row3_col14,#T_a183b_row3_col16,#T_a183b_row3_col18,#T_a183b_row3_col20,#T_a183b_row3_col22,#T_a183b_row4_col0,#T