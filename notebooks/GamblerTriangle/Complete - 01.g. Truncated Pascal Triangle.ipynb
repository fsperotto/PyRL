# %% [markdown]
# # Truncating the Pascal Triangle

# %% [markdown]
# The Pascal triagle starts with value $1$ at the origin cell $(0, 0)$, and the value $0$ on the other cells of such first row, the cells on the next rows are calculated by adding the immediate upper and upper-left neighbor cells.
# It forms a lower/left triangular matrix.
#
# It can be defined recursivelly, based on the first row, as follows:
#
# $\forall \ n \in \mathbb{N}, k \in \mathbb{Z} :$
#
# $$ \mathcal{Z}\binom{n}{k} = \begin{cases}
#   \binom{n}{k} \ & \text{ if } n \geq k \geq 0\\
#   0 & \text{otherwise}
# \end{cases}$$
#
# ## $h$-Truncated Pascal Triangle
#
# Thanks to the symetry of the triangle, it can be truncated latteraly at limit $h$ by subtracting a $h$-shifted triangle:
#
# $\begin{align}
# \mathcal{T}\!\mathcal{runc}_h\mathcal{Z}\binom{n}{k}
#  & = \mathcal{Z}\binom{n}{k} - \mathcal{Shift}_{h}\mathcal{Z}\binom{n}{k} \\
#  & = \mathcal{Z}\binom{n}{k} - \mathcal{Z}\binom{n}{k-h} \\
#  & = \begin{cases}
#  \binom{n}{k} - \binom{n}{k-h} & \text{ if } n \geq k \geq 0 \text{ and } n \geq (k-h) \geq 0\\
#  \binom{n}{k}  & \text{ if } n \geq k \geq 0 \text{ but either } (k-h) > n \text{ or } (k-h) < 0\\
#  - \binom{n}{k-h} & \text{ if } n \geq (k-h) \geq 0 \text{ but either } k > n \text{ or } k < 0\\
#  0 & \text{ otherwise}
# \end{cases}
# \end{align}$
#
# See: https://arxiv.org/abs/1807.08181
#
# See also: https://link.springer.com/article/10.1023%2FA%3A1004636216365

# %%
from pyrl.gr import *
from pyrl.utils import *

################

max_k = 20
k_arr = range(-3,max_k+1)
n_arr = range(-3,max_k+1)

printdf([[trunc_pascal_triangle(n, k, 1) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='$1$-Truncated Pascal Triangle:')
printdf([[trunc_pascal_triangle(n, k, 5) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='$5$-Truncated Pascal Triangle:')
printdf([[trunc_pascal_triangle(n, k, -1) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='$-1$-Truncated Pascal Triangle:')
printdf([[trunc_pascal_triangle(n, k, -5) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='$-5$-Truncated Pascal Triangle:')
# Out:
# D:\fperotto\SourceCode\PyRL\src\pyrl\utils.py:54: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   dfs = dfs.applymap(lambda v : "color: lightgray" if v==0 else ("color: yellow" if v<0 else "color: black") )
# <h3>$1$-Truncated Pascal Triangle:</h3>
# <style type="text/css">
# #T_35e8b th.row_heading {
#   border-right: 1px solid black;
# }
# #T_35e8b th.index_name {
#   border-right: 1px solid black;
# }
# #T_35e8b td {
#   padding: 2px;
#   margin: 0;
# }
# #T_35e8b th {
#   padding: 2px;
#   margin: 0;
# }
# #T_35e8b td.row3 {
#   border-top: 1px dotted grey;
#   border-bottom: 1px dotted grey;
# }
# #T_35e8b td.col3 {
#   border-left: 1px dotted grey;
#   border-right: 1px dotted grey;
# }
# <h3>$5$-Truncated Pascal Triangle:</h3>
# <style type="text/css">
# #T_c1a47 th.row_heading {
#   border-right: 1px solid black;
# }
# #T_c1a47 th.index_name {
#   border-right: 1px solid black;
# }
# #T_c1a47 td {
#   padding: 2px;
#   margin: 0;
# }
# #T_c1a47 th {
#   padding: 2px;
#   margin: 0;
# }
# #T_c1a47 td.row3 {
#   border-top: 1px dotted grey;
#   border-bottom: 1px dotted grey;
# }
# #T_c1a47 td.col3 {
#   border-left: 1px dotted grey;
#   border-right: 1px dotted grey;
# }
# #T_c1a47_row0_col0, #T_c1a47_row0_col1, #T_c1a47_row0_col2, #T_c1a47_row0_col3, #T_c1a47_row0_col4, #T_c1a47_row0_col5, #T_c1a47_row0_col6, #T_c1a47_row0_col7, #T_c1a47_row0_col8, #T_c1a47_row0_col9, #T_c1a47_row0_col10, #T_c1a47_row0_col11, #T_c1a47_row0_col12, #T_c1a47_row0_col13, #T_c1a47_row0_col14, #T_c1a47_row0_col15, #T_c1a47_row0_col16, #T_c1a47_row0_col17, #T_c1a47_row0_col18, #T_c1a47_row0_col19, #T_c1a47_row0_col20, #T_c1a47_row0_col21, #T_c1a47_row0_col22, #T_c1a47_row0_col23, #T_c1a47_row1_col0, #T_c1a47_row1_col1, #T_c1a47_row1_col2, #T_c1a47_row1_col3, #T_c1a47_row1_col4, #T_c1a47_row1_col5, #T_c1a47_row1_col6, #T_c1a47_row1_col7, #T_c1a47_row1_col8, #T_c1a47_row1_col9, #T_c1a47_row1_col10, #T_c1a47_row1_col11, #T_c1a47_row1_col12, #T_c1a47_row1_col13, #T_c1a47_row1_col14, #T_c1a47_row1_col15, #T_c1a47_row1_col16, #T_c1a47_row1_col17, #T_c1a47_row1_col18, #T_c1a47_row1_col19, #T_c1a47_row1_col20, #T_c1a47_row1_col21, #T_c1a47_row1_col22, #T_c1a47_row1_col23, #T_c1a47_row2_col0, #T_c1a47_row2_col1, #T_c1a47_row2_col2, #T_c1a47_row2_col3, #T_c1a47_row2_col4, #T_c1a47_row2_col5, #T_c1a47_row2_col6, #T_c1a47_row2_col7, #T_c1a47_row2_col8, #T_c1a47_row2_col9, #T_c1a47_row2_col10, #T_c1a47_row2_col11, #T_c1a47_row2_col12, #T_c1a47_row2_col13, #T_c1a47_row2_col14, #T_c1a47_row2_col15, #T_c1a47_row2_col16, #T_c1a47_row2_col17, #T_c1a47_row2_col18, #T_c1a47_row2_col19, #T_c1a47_row2_col20, #T_c1a47_row2_col21, #T_c1a47_row2_col22, #T_c1a47_row2_col23, #T_c1a47_row3_col0, #T_c1a47_row3_col1, #T_c1a47_row3_col2, #T_c1a47_row3_col4, #T_c1a47_row3_col5, #T_c1a47_row3_col6, #T_c1a
# #T_27ab7 th.index_name {
#   border-right: 1px solid black;
# }
# #T_27ab7 td {
#   padding: 2px;
#   margin: 0;
# }
# #T_27ab7 th {
#   padding: 2px;
#   margin: 0;
# }
# #T_27ab7 td.row3 {
#   border-top: 1px dotted grey;
#   border-bottom: 1px dotted grey;
# }
# #T_27ab7 td.col3 {
#   border-left: 1px dotted grey;
#   border-right: 1px dotted grey;
# }
# #T_27ab7_row0_col0, #T_27ab7_row0_col1, #T_27ab7_row0_col2, #T_27ab7_row0_col3, #T_27ab7_row0_col4, #T_27ab7_row0_col5, #T_27ab7_row0_col6, #T_27ab7_row0_col7, #T_27ab7_row0_col8, #T_27ab7_row0_col9, #T_27ab7_row0_col10, #T_27ab7_row0_col11, #T_27ab7_row0_col12, #T_27ab7_row0_col13, #T_27ab7_row0_col14, #T_27ab7_row0_col15, #T_27ab7_row0_col16, #T_27ab7_row0_col17, #T_27ab7_row0_col18, #T_27ab7_row0_col19, #T_27ab7_row0_col20, #T_27ab7_row0_col21, #T_27ab7_row0_col22, #T_27ab7_row0_col23, #T_27ab7_row1_col0, #T_27ab7_row1_col1, #T_27ab7_row1_col2, #T_27ab7_row1_col3, #T_27ab7_row1_col4, #T_27ab7_row1_col5, #T_27ab7_row1_col6, #T_27ab7_row1_col7, #T_27ab7_row1_col8, #T_27ab7_row1_col9, #T_27ab7_row1_col10, #T_27ab7_row1_col11, #T_27ab7_row1_col12, #T_27ab7_row1_col13, #T_27ab7_row1_col14, #T_27ab7_row1_col15, #T_27ab7_row1_col16, #T_27ab7_row1_col17, #T_27ab7_row1_col18, #T_27ab7_row1_col19, #T_27ab7_row1_col20, #T_27ab7_row1_col21, #T_27ab7_row1_col22, #T_27ab7_row1_col23, #T_27ab7_row2_col0, #T_27ab7_row2_col1, #T_27ab7_row2_col2, #T_27ab7_row2_col3, #T_27ab7_row2_col4, #T_27ab7_row2_col5, #T_27ab7_row2_col6, #T_27ab7_row2_col7, #T_27ab7_row2_col8, #T_27ab7_row2_col9, #T_27ab7_row2_col10, #T_27ab7_row2_col11, #T_27ab7_row2_col12, #T_27ab7_row2_col13, #T_27ab7_row2_col14, #T_27ab7_row2_col15, #T_27ab7_row2_col16, #T_27ab7_row2_col17, #T_27ab7_row2_col18, #T_27ab7_row2_col19, #T_27ab7_row2_col20, #T_27ab7_row2_col21, #T_27ab7_row2_col22, #T_27ab7_row2_col23, #T_27ab7_row3_col0, #T_27ab7_row3_col1, #T_27ab7_row3_col4, #T_27ab7_row3_col5, #T_27ab7_row3_col6, #T_27ab7_row3_col7, #T_27ab7_row3_col8, #T_27ab7_row3_col9, #T_27ab7_row3_col10, #T_27ab7_row3_col11, #T_27ab7_row3_col12, #T_27ab7_row3_col13, #T_27ab7_row3_col14, #T_27ab7_row3_col15, #T_27ab7_row3_col16, #T_27ab7_row3_col17, #T_27ab7_row3_col18, #T_27ab7_row3_col19, #T_27ab7_row3_col20, #T_27ab7_row3
# #T_27ab7_row3_col2, #T_27ab7_row4_col2, #T_27ab7_row5_col2, #T_27ab7_row5_col3, #T_27ab7_row6_col2, #T_27ab7_row6_col3, #T_27ab7_row7_col2, #T_27ab7_row7_col3, #T_27ab7_row7_col4, #T_27ab7_row8_col2, #T_27ab7_row8_col3, #T_27ab7_row8_col4, #T_27ab7_row9_col2, #T_27ab7_row9_col3, #T_27ab7_row9_col4, #T_27ab7_row9_col5, #T_27ab7_row10_col2, #T_27ab7_row10_col3, #T_27ab7_row10_col4, #T_27ab7_row10_col5, #T_27ab7_row11_col2, #T_27ab7_row11_col3, #T_27ab7_row11_col4, #T_27ab7_row11_col5, #T_27ab7_row11_col6, #T_27ab7_row12_col2,
# <h3>$-5$-Truncated Pascal Triangle:</h3>
# <style type="text/css">
# #T_a0aa2 th.row_heading {
#   border-right: 1px solid black;
# }
# #T_a0aa2 th.index_name {
#   border-right: 1px solid black;
# }
# #T_a0aa2 td {
#   padding: 2px;
#   margin: 0;
# }
# #T_a0aa2 th {
#   padding: 2px;
#   margin: 0;
# }
# #T_a0aa2 td.row3 {
#   border-top: 1px dotted grey;
#   border-bottom: 1px dotted grey;
# }
# #T_a0aa2 td.col3 {
#   border-left: 1px dotted grey;
#   border-right: 1px dotted grey;
# }
# #T_a0aa2_row0_col0, #T_a0aa2_row0_col1, #T_a0aa2_row0_col2, #T_a0aa2_row0_col3, #T_a0aa2_row0_col4, #T_a0aa2_row0_col5, #T_a0aa2_row0_col6, #T_a0aa2_row0_col7, #T_a0aa2_row0_col8, #T_a0aa2_row0_col9, #T_a0aa2_row0_col10, #T_a0aa2_row0_col11, #T_a0aa2_row0_col12, #T_a0aa2_row0_col13, #T_a0aa2_row0_col14, #T_a0aa2_row0_col15, #T_a0aa2_row0_col16, #T_a0aa2_row0_col17, #T_a0aa2_row0_col18, #T_a0aa2_row0_col19, #T_a0aa2_row0_col20, #T_a0aa2_row0_col21, #T_a0aa2_row0_col22, #T_a0aa2_row0_col23, #T_a0aa2_row1_col0, #T_a0aa2_row1_col1, #T_a0aa2_row1_col2, #T_a0aa2_row1_col3, #T_a0aa2_row1_col4, #T_a0aa2_row1_col5, #T_a0aa2_row1_col6, #T_a0aa2_row1_col7, #T_a0aa2_row1_col8, #T_a0aa2_row1_col9, #T_a0aa2_row1_col10, #T_a0aa2_row1_col11, #T_a0aa2_row1_col12, #T_a0aa2_row1_col13, #T_a0aa2_row1_col14, #T_a0aa2_row1_col15, #T_a0aa2_row1_col16, #T_a0aa2_row1_col17, #T_a0aa2_row1_col18, #T_a0aa2_row1_col19, #T_a0aa2_row1_col20, #T_a0aa2_row1_col21, #T_a0aa2_row1_col22, #T_a0aa2_row1_col23, #T_a0aa2_row2_col0, #T_a0aa2_row2_col1, #T_a0aa2_row2_col2, #T_a0aa2_row2_col3, #T_a0aa2_row2_col4, #T_a0aa2_row2_col5, #T_a0aa2_row2_col6, #T_a0aa2_row2_col7, #T_a0aa2_row2_col8, #T_a0aa2_row2_col9, #T_a0aa2_row2_col10, #T_a0aa2_row2_col11, #T_a0aa2_row2_col12, #T_a0aa2_row2_col13, #T_a0aa2_row2_col14, #T_a0aa2_row2_col15, #T_a0aa2_row2_col16, #T_a0aa2_row2_col17, #T_a0aa2_row2_col18, #T_a0aa2_row2_col19, #T_a0aa2_row2_col20, #T_a0aa2_row2_col21, #T_a0aa2_row2_col22, #T_a0aa2_row2_col23, #T_a0aa2_row3_col0, #T_a0aa2_row3_col1, #T_a0aa2_row3_col2, #T_a0aa2_row3_col4, #T_a0aa2_row3_col5, #T_a0aa2_row3_col6, #T_a0aa2_row3_col7, #T_a0aa2_row3_col8, #T_a0aa2_row3_col9, #T_a0aa2_row3_col10, #T_a0aa2_row3_col11, #T_a0aa2_row3_col12, #T_a0aa2_row3_col13, #T_a0aa2_row3_col14, #T_a0aa2_row3_col15, #T_a0aa2_row3_col16, #T_a0aa2_row3_col17, #T_a0aa2_row3_col18, #T_a0aa2_row3_col19, #T_a0aa2_row3_col20, #T_a0aa2_row3_col21, #T_a0aa2_row3_col22, #T_a0aa2_row3_col23, #T_a0aa2_row4_col0, #T_a0aa2_row4_col1, #T_a0aa2_row4_col2, #T_a0aa2_row4_col5, #T_a0aa2_row4_col6, #T_a0aa2_row4_col7, #T_a0aa2_row4_col8, #T_a0aa2_row4_col9, #T_a0aa2_row4_col10, #T_a0aa2_row4_col11, #T_a0aa2_row4_col12, #T_a0aa2_row4_col13, #T_a0aa2_row4_col14, #T_a0aa2_row4_col15, #T_a0aa2_row4_col16, #T_a0aa2_row4_col17, #T_a0aa2_row4_col18, #T_a0aa2_row4_col19, #T_a0aa2_row4_col20, #T_a0aa2_row4_col21, #T_a0aa2_row4_col22, #T_a0aa2_row4_col23, #T_a0aa2_row5_col1, #T_a0aa2_row5_col2, #T_a0aa2_row5_col6, #T_a0aa2_row5_col7, #T_a0aa2_row5_col8, #T_a0aa2_row5_col9, #T_a0aa2_row5_col10, #T_a0aa2_row5_col11, #T_a0aa2_row5_col12, #T_a0aa2_row5_col13, #T_a0aa2_row5_col14, #T_a0aa2_row5_col15, #T_a0aa2_row5_col16, #T_a0aa2_row5_col17, #T_a0aa2_row5_col18, #T_a0aa2_row5_col19, #T_a0aa2_row5_col20, #T_a0aa2_row5_col21, #T_a0aa2_row5_col22, #T_a0aa2_row5_col23, #T_a0aa2_row6_col2, #T_a0aa2_row6_col7, #T_a0aa2_row6_col8, #T_a0aa2_row6_col9, #T_a0aa2_row6_col10, #T_a0aa2_row6_col11, #T_a0aa2_row6_col12, #T_a0aa2_row6_col13, #T_a0aa2_row6_col14, #T_a0aa2_row6_col15, #T_a0aa2_row6_col16, #T_a0aa2_row6_col17, #T_a0aa2_row6_col18, #T_a0aa2_row6_col19, #T_a0aa2_row6_col20, #T_a0aa2_row6_col21, #T_a0aa2_row6_col22, #T_a0aa2_row6_col23, #T_a0aa2_row7_col8, #T_a0aa2_row7_col9, #T_a0aa2_row7_col10, #T_a0aa2_row7_col11, #T_a0aa2_row7_col12, #T_a0aa2_row7_col13, #T_a0aa2_row7_col14, #T_a0aa2_row7_col15, #T_a0aa2_row7_col16, #T_a0aa2_row7_col17, #T_a0aa2_row7_col18, #T_a0aa2_row7_col19, #T_a0aa2_row7_col20, #T_a0aa2_row7_col21, #T_a0aa2_row7_col22, #T_a0aa2_row7_col23, #T_a0aa2_row8_col3, #T_a0aa2_row8_col9, #T_a0aa2_row8_col10, #T_a0aa2_row8_col11, #T_a0aa2_row8_col12, #T_a0aa2_row8_col13, #T_a0aa2_row8_col14, #T_a0aa2_row8_col15, #T_a0aa2_row8_col16, #T_a0aa2_row8_col17, #T_a0aa2_row8_col18, #T_a0aa2_row8_col19, #T_a0aa2_row8_col20, #T_a0aa2_row8_col21, #T_a0aa2_row8_col22, #T_a0aa2_row8_col23, #T_a0aa2_row9_col10, #T_a0aa2_row9_col11, #T_a0aa2_row9_col12, #T_a0aa2_row9_col13, #T_a0aa2_row9_col14, #T_a0aa2_row9_col15, #T_a0aa2 ...
#   color: lightgray;
# }
# #T_a0aa2_row3_col3, #T_a0aa2_row4_col3, #T_a0aa2_row4_col4, #T_a0aa2_row5_col3, #T_a0aa2_row5_col4, #T_a0aa2_row5_col5, #T_a0aa2_row6_col3, #T_a0aa2_row6_col4, #T_a0aa2_row6_col5, #T_a0aa2_row6_col6, #T_a0aa2_row7_col3, #T_a0aa2_row7_col4, #T_a0aa2_row7_col5, #T_a0aa2_row7_col6, #T_a0aa2_row7_col7, #T_a0aa2_row8_col4, #T_a0aa2_row8_col5, #T_a0aa2_row8_col6, #T_a0aa2_row8_col7, #T_a0aa2_row8_col8, #T_a0aa2_row9_col4, #T_a0aa2_row9_col5, #T_a0aa2_row9_col6, #T_a0aa2_row9_col7, #T_a0aa2_row9_col8, #T_a0aa2_row9_col9, #T_a0aa2_row10_col5, #T_a0aa2_row10_col6, #T_a0aa2_row10_col7, #T_a0aa2_row10_col8, #T_a0aa2_row10_col9, #T_a0aa2_row10_col10, #T_a0aa2_row11_col5, #T_a0aa2_row11_col6, #T_a0aa2_row11_col7, #T_a0aa2_row11_col8, #T_a0aa2_row11_col9, #T_a0aa2_row11_col10, #T_a0aa2_row11_col11, #T_a0aa2_row12_col6, #T_a0aa2_row12_col7, #T_a0aa2_row12_col8, #T_a0aa2_row12_col9, #T_a0aa2_row12_col10, #T_a0aa2_row12_col11, #T_a0aa2_row12_col12, #T_a0aa2_row13_col6, #T_a0aa2_row13_col7, #T_a0aa2_row13_col8, #T_a0aa2_row13_col9, #T_a0aa2_row13_col10, #T_a0aa2_row13_col11, #T_a0aa2_row13_col12, #T_a0aa2_row13_col13, #T_a0aa2_row14_col7, #T_a0aa2_row14_col8, #T_a0aa2_row14_col9, #T_a0aa2_row14_col10, #T_a0aa2_row14_col11, #T_a0aa2_row14_col12, #T_a0aa2_row1
