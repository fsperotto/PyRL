# %% [markdown]
# # Pascal Triangle and the Binomial Coefficient

# %% [markdown]
# ## Brief History
#
# What is called "Pascal's triangle" in the Occident was known centuries before Blaise Pascal. But Pascal published the earliest known mathematical treatise about the triangle (Traité du triangle arithmétique, 1654), where he proved several of its properties (including the binomial correspondence) by inductive reasoning, and linked it to problems in probability theory.
#
# <img src="img/pascal_triangle.png" width=600 height=auto />
#
# ## Definition
#
# The Pascal's triangle is classically defined as a triangular matrix on the space $\mathbb{N} \times \mathbb{N}$ of naturals numbers.
#
# In the most common representation, the value $1$ is written into the first column, $k = 0$, and the value $0$ into the cells of the first row, $n=0$, except the first cell.
# The cells on the other rows are calculated recursivelly by adding the immediate upper and upper-left neighbor cells:
#
# $\forall \ n, k \in \mathbb{N} :$
#
# $$ C(n, k) \ = \ C^k_n \ = \ {}_nC_k \ = \ \begin{cases}
#   0 & \text{if } n=0 \text{ and } k>0 \\
#   1 & \text{if } k=0 \\
#   C(n-1, k-1) + C(n-1, k) & \text{otherwise}
# \end{cases}$$
#
# It forms a lower/left triangular matrix, then the definition can be simplified, as follows:
#
# $$ C(n, k) \ = \ C^k_n \ = \ {}_nC_k \ = \ \begin{cases}
#   0 & \text{if } k>n \\
#   1 & \text{if } k=0 \\
#   C(n-1, k-1) + C(n-1, k) & \text{otherwise}
# \end{cases}$$
#
# Each non-zero element can be calculated directly using the binomial coefficient:
#
# $ \forall \ n, k \in \mathbb{N} \mid n \geq k \geq 0 $ :
#
# $$ C(n, k)
# \ = \ \binom{n}{k}
# \ = \ \frac{n!}{k!(n-k)!}
# \ = \ \frac{\Gamma(n+1)}{\Gamma(k+1)\Gamma(n-k+1)}
# \ = \ \frac{n^{\underline{k}}}{k!} $$

# %%
from srl.gr import *
from srl.utils import printdf

################

max_n = 20
k_arr = range(0,max_n+1)
n_arr = range(0,max_n+1)

printdf([[zcomb(n, k) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='Classic Pascal Triangle (lower triangular matrix), $C(n,k)$:')
printdf([[zcomb(n, k) for k in k_arr] for n in n_arr], label_rows=n_arr, label_cols=k_arr, label_axis_cols="k", label_axis_rows="n", title='Gambling Pascal Triangle (transposed reversed presentation):', transpose=True, reverse=True)
# Out:
# <h3>Classic Pascal Triangle (lower triangular matrix), $C(n,k)$:</h3>
# <style  type="text/css" >
#     #T_eb5c4_ th.row_heading {
#           border-right: 1px solid black;
#     }    #T_eb5c4_ th.index_name {
#           border-right: 1px solid black;
#     }    #T_eb5c4_ td {
#           padding: 2px;
#           margin: 0;
#     }    #T_eb5c4_ th {
#           padding: 2px;
#           margin: 0;
#     }    #T_eb5c4_ td.row0 {
#           border-top: 1px dotted grey;
#           border-bottom: 1px dotted grey;
#     }    #T_eb5c4_ td.col0 {
#           border-left: 1px dotted grey;
#           border-right: 1px dotted grey;
#     }#T_eb5c4_row0_col0,#T_eb5c4_row1_col0,#T_eb5c4_row1_col1,#T_eb5c4_row2_col0,#T_eb5c4_row2_col1,#T_eb5c4_row2_col2,#T_eb5c4_row3_col0,#T_eb5c4_row3_col1,#T_eb5c4_row3_col2,#T_eb5c4_row3_col3,#T_eb5c4_row4_col0,#T_eb5c4_row4_col1,#T_eb5c4_row4_col2,#T_eb5c4_row4_col3,#T_eb5c4_row4_col4,#T_eb5c4_row5_col0,#T_eb5c4_row5_col1,#T_eb5c4_row5_col2,#T_eb5c4_row5_col3,#T_eb5c4_row5_col4,#T_eb5c4_row5_col5,#T_eb5c4_row6_col0,#T_eb5c4_row6_col1,#T_eb5c4_row6_col2,#T_eb5c4_row6_col3,#T_eb5c4_row6_col4,#T_eb5c4_row6_col5,#T_eb5c4_row6_col6,#T_eb5c4_row7_col0,#T_eb5c4_row7_col1,#T_eb5c4_row7_col2,#T_eb5c4_row7_col3,#T_eb5c4_row7_col4,#T_eb5c4_row7_col5,#T_eb5c4_row7_col6,#T_eb5c4_row7_col7,#T_eb5c4_row8_col0,#T_eb5c4_row8_col1,#T_eb5c4_row8_col2,#T_eb5c4_row8_col3,#T_eb5c4_row8_col4,#T_eb5c4_row8_col5,#T_eb5c4_row8_col6,#T_eb5c4_row8_col7,#T_eb5c4_row8_col8,#T_eb5c4_row9_col0,#T_eb5c4_row9_col1,#T_eb5c4_row9_col2,#T_eb5c4_row9_col3,#T_eb5c4_row9_col4,#T_eb5c4_row9_col5,#T_eb5c4_row9_col6,#T_eb5c4_row9_col7,#T_eb5c4_row9_col8,#T_eb5c4_row9_col9,#T_eb5c4_row10_col0,#T_eb5c4_row10_col1,#T_eb5c4_row10_col2,#T_eb5c4_row10_col3,#T_eb5c4_row10_col4,#T_eb5c4_row10_col5,#T_eb5c4_row10_col6,#T_eb5c4_row10_col7,#T_eb5c4_row10_col8,#T_eb5c4_row10_col9,#T_eb5c4_row10_col10,#T_eb5c4_row11_col0,#T_eb5c4_row11_col1,#T_eb5c4_row11_col2,#T_eb5c4_row11_col3,#T_eb5c4_row11_col4,#T_eb5c4_row11_col5,#T_eb5c4_row11_col6,#T_eb5c4_row11_col7,#T_eb5c4_row11_col8,#T_eb5c4_row11_col9,#T_eb5c4_row11_col10,#T_eb5c4_row11_col11,#T_eb5c4_row12_col0,#T_eb5c4_row12_col1,#T_eb5c4_row12_col2,#T_eb5c4_row12_col3,#T_eb5c4_row12_col4,#T_eb5c4_row12_col5,#T_eb5c4_row12_col6,#T_eb5c4_row12_col7,#T_eb5c4_row12_col8,#T_eb5c4_row12_col9,#T_eb5c4_row12_col10,#T_eb5c4_row12_col11,#T_eb5c4_row12_col12,#T_eb5c4_row13_col0,#T_eb5c4_row13_col1,#T_eb5c4_row13_col2,#T_eb5c4_row13_col3,#T_eb5c4_row13_col4,#T_eb5c4_row13_col5,#T_eb5c4_row13_col6,#T_eb5c4_row13_col7,#T_eb5c4_row13_col8,#T_eb5c4_row13_col9,#T_eb5c4_row13_col10,#T_eb5c4_row13_col11,#T_eb5c4_row13_col12,#T_eb5c4_row13_col13,#T_eb5c4_row14_col0,#T_eb5c4_row14_col1,#T_eb5c4_row14_col2,#T_eb5c4_row14_col3,#T_eb5c4_row14_col4,#T_eb5c4_row14_col5,#T_eb5c4_row14_col6,#T_eb5c4_row14_col7,#T_eb5c4_row14_col8,#T_eb5c4_row14_col9,#T_eb5c4_row14_col10,#T_eb5c4_row14_col11,#T_eb5c4_row14_col12,#T_eb5c4_row14_col13,#T_eb5c4_row14_col14,#T_eb5c4_row15_col0,#T_eb5c4_row15_col1,#T_eb5c4_row15_col2,#T_eb5c4_row15_col3,#T_eb5c4_row15_col4,#T_eb5c4_row15_col5,#T_eb5c4_row15_col6,#T_eb5c4_row15_col7,#T_eb5c4_row15_col8,#T_eb5c4_row15_col9,#T_eb5c4_row15_col10,#T_eb5c4_row15_col11,#T_eb5c4_row15_col12,#T_eb5c4_row15_col13,#T_eb5c4_row15_col14,#T_eb5c4_row15_col15,#T_eb5c4_row16_col0,#T_eb5c4_row16_col1,#T_eb5c4_row16_col2,#T_eb5c4_row16_col3,#T_eb5c4_row16_col4,#T_eb5c4_row16_col5,#T_eb5c4_row16_col6,#T_eb5c4_row16_col7,#T_eb5c4_row16_col8,#T_eb5c4_row16_col9,#T_eb5c4_row16_col10,#T_eb5c4_row16_col11,#T_eb5c4_row16_col12,#T_eb5c4_row16_col13,#T_eb5c4_row16_col14,#T_eb5c4_row16_col15,#T_eb5c4_row16_col16,#T_eb5c4_row17_col0,#T_eb5c4_row17_col1,#T_eb5c4_row17_col2,#T_eb5c4_row17_col3,#T_eb5c4_row17_col4,#T_eb5c4_row17_col5,#T_eb5c4_row17_col6,#T_eb5c4_row17_col7,#T_eb5c4_row17_col8,#T_eb5c4_row17_col9,#T_eb5c4_row17_col10,#T_eb5c4_row17_col11,#T_eb5c4_row17_col12,#T_eb5c4_row17_col13,#T_eb5c4_row17_col14,#T_eb5c4_row17_col15,#T_eb5c4_row17_col16,#T_eb5c4_row17_col17,#T_eb5c4_row18_col0,#T_eb5c4_row18_col1,#T_eb5c4_row18_col2,#T_eb5c4_row18_col3,#T_eb5c4_row18_col4,#T_eb5c4_row18_col5,#T_eb5c4_row18_col6,#T_eb5c4_row18_col7,#T_eb5c4_row18_col8,#T_eb5c4_row18_col9,#T_eb5c4_row18_col10,#T_eb5c4_row18_col11,#T_eb5c4_row18_col12,#T_eb5c4_row18_col13,#T_eb5c4_row18_col14,#T_eb5c4_row18_col15,#T_eb5c4_row18_col16,#T_eb5c4_row18_col17,#T_eb5c4_row18_col18,#T_eb5c4_row19_col0,#T_eb5c4_row19_col1,#T_eb5c4_row19_col2,#T_eb5c4_row19_col3,#T_eb5c4_row19_col4,#T_eb5c4_row19_col5,#T_eb5c4_row19_col6,#T_eb5c4_row19_col7,#T_eb5c4_row19_col8,#T_eb5c4_row19_col9,#T_eb ...
#             color:  black;
#         }#T_eb5c4_row0_col1,#T_eb5c4_row0_col2,#T_eb5c4_row0_col3,#T_eb5c4_row0_col4,#T_eb5c4_row0_col5,#T_eb5c4_row0_col6,#T_eb5c4_row0_col7,#T_eb5c4_row0_col8,#T_eb5c4_row0_col9,#T_eb5c4_row0_col10,#T_eb5c4_row0_col11,#T_eb5c4_row0_col12,#T_eb5c4_row0_col13,#T_eb5c4_row0_col14,#T_eb5c4_row0_col15,#T_eb5c4_row0_col16,#T_eb5c4_row0_col17,#T_eb5c4_row0_col18,#T_eb5c4_row0_col19,#T_eb5c4_row0_col20,#T_eb5c4_row1_col2,#T_eb5c4_row1_col3,#T_eb5c4_row1_col4,#T_eb5c4_row1_col5,#T_eb5c4_row1_col6,#T_eb5c4_row1_col7,#T_eb5c4_row1_col8,#T_eb5c4_row1_col9,#T_eb5c4_row1_col10,#T_eb5c4_row1_col11,#T_eb5c4_row1_col12,#T_eb5c4_row1_col13,#T_eb5c4_row1_col14,#T_eb5c4_row1_col15,#T_eb5c4_row1_col16,#T_eb5c4_row1_col17,#T_eb5c4_row1_col18,#T_eb5c4_row1_col19,#T_eb5c4_row1_col20,#T_eb5c4_row2_col3,#T_eb5c4_row2_col4,#T_eb5c4_row2_col5,#T_eb5c4_row2_col6,#T_eb5c4_row2_col7,#T_eb5c4_row2_col8,#T_eb5c4_row2_col9,#T_eb5c4_row2_col10,#T_eb5c4_row2_col11,#T_eb5c4_row2_col12,#T_eb5c4_row2_col13,#T_eb5c4_row2_col14,#T_eb5c4_row2_col15,#T_eb5c4_row2_col16,#T_eb5c4_row2_col17,#T_eb5c4_row2_col18,#T_eb5c4_row2_col19,#T_eb5c4_row2_col20,#T_eb5c4_row3_col4,#T_eb5c4_row3_col5,#T_eb5c4_row3_col6,#T_eb5c4_row3_col7,#T_eb5c4_row3_col8,#T_eb5c4_row3_col9,#T_eb5c4_row3_col10,#T_eb5c4_row3_col11,#T_eb5c4_row3_col12,#T_eb5c4_row3_col13,#T_eb5c4_row3_col14,#T_eb5c4_row3_col15,#T_eb5c4_row3_col16,#T_eb5c4_row3_col17,#T_eb5c4_row3_col18,#T_eb5c4_row3_col19,#T_eb5c4_row3_col20,#T_eb5c4_row4_col5,#T_eb5c4_row4_col6,#T_eb5c4_row4_col7,#T_eb5c4_row4_col8,#T_eb5c4_row4_col9,#T_eb5c4_row4_col10,#T_eb5c4_row4_col11,#T_eb5c4_row4_col12,#T_eb5c4_row4_col13,#T_eb5c4_row4_col14,#T_eb5c4_row4_col15,#T_eb5c4_row4_col16,#T_eb5c4_row4_col17,#T_eb5c4_row4_col18,#T_eb5c4_row4_col19,#T_eb5c4_row4_col20,#T_eb5c4_row5_col6,#T_eb5c4_row5_col7,#T_eb5c4_row5_col8,#T_eb5c4_row5_col9,#T_eb5c4_row5_col10,#T_eb5c4_row5_col11,#T_eb5c4_row5_col12,#T_eb5c4_row5_col13,#T_eb5c4_row5_col14,#T_eb5c4_row5_col15,#T_eb5c4_row5_col16,#T_eb5c4_row5_col17,#T_eb5c4_row5_col18,#T_eb5c4_row5_col19,#T_eb5c4_row5_col20,#T_eb5c4_row6_col7,#T_eb5c4_row6_col8,#T_eb5c4_row6_col9,#T_eb5c4_row6_col10,#T_eb5c4_row6_col11,#T_eb5c4_row6_col12,#T_eb5c4_row6_col13,#T_eb5c4_row6_col14,#T_eb5c4_row6_col15,#T_eb5c4_row6_col16,#T_eb5c4_row6_col17,#T_eb5c4_row6_col18,#T_eb5c4_row6_col19,#T_eb5c4_row6_col20,#T_eb5c4_row7_col8,#T_eb5c4_row7_col9,#T_eb5c4_row7_col10,#T_eb5c4_row7_col11,#T_eb5c4_row7_col12,#T_eb5c4_row7_col13,#T_eb5c4_row7_col14,#T_eb5c4_row7_col15,#T_eb5c4_row7_col16,#T_eb5c4_row7_col17,#T_eb5c4_row7_col18,#T_eb5c4_row7_col19,#T_eb5c4_row7_col20,#T_eb5c4_row8_col9,#T_eb5c4_row8_col10,#T_eb5c4_row8_col11,#T_eb5c4_row8_col12,#T_eb5c4_row8_col13,#T_eb5c4_row8_col14,#T_eb5c4_row8_col15,#T_eb5c4_row8_col16,#T_eb5c4_row8_col17,#T_eb5c4_row8_col18,
# <h3>Gambling Pascal Triangle (transposed reversed presentation):</h3>
# <style  type="text/css" >
#     #T_52ef7_ th.row_heading {
#           border-right: 1px solid black;
#     }    #T_52ef7_ th.index_name {
#           border-right: 1px solid black;
#     }    #T_52ef7_ td {
#           padding: 2px;
#           margin: 0;
#     }    #T_52ef7_ th {
#           padding: 2px;
#           margin: 0;
#     }    #T_52ef7_ td.row20 {
#           border-top: 1px dotted grey;
#           border-bottom: 1px dotted grey;
#     }    #T_52ef7_ td.col0 {
#           border-left: 1px dotted grey;
#           border-right: 1px dotted grey;
#     }#T_52ef7_row0_col0,#T_52ef7_row0_col1,#T_52ef7_row0_col2,#T_52ef7_row0_col3,#T_52ef7_row0_col4,#T_52ef7_row0_col5,#T_52ef7_row0_col6,#T_52ef7_row0_col7,#T_52ef7_row0_col8,#T_52ef7_row0_col9,#T_52ef7_row0_col10,#T_52ef7_row0_col11,#T_52ef7_row0_col12,#T_52ef7_row0_col13,#T_52ef7_row0_col14,#T_52ef7_row0_col15,#T_52ef7_row0_col16,#T_52ef7_row0_col17,#T_52ef7_row0_col18,#T_52ef7_row0_col19,#T_52ef7_row1_col0,#T_52ef7_row1_col1,#T_52ef7_row1_col2,#T_52ef7_row1_col3,#T_52ef7_row1_col4,#T_52ef7_row1_col5,#T_52ef7_row1_col6,#T_52ef7_row1_col7,#T_52ef7_row1_col8,#T_52ef7_row1_col9,#T_52ef7_row1_col10,#T_52ef7_row1_col11,#T_52ef7_row1_col12,#T_52ef7_row1_col13,#T_52ef7_row1_col14,#T_52ef7_row1_col15,#T_52ef7_row1_col16,#T_52ef7_row1_col17,#T_52ef7_row1_col18,#T_52ef7_row2_col0,#T_52ef7_row2_col1,#T_52ef7_row2_col2,#T_52ef7_row2_col3,#T_52ef7_row2_col4,#T_52ef7_row2_col5,#T_52ef7_row2_col6,#T_52ef7_row2_col7,#T_52ef7_row2_col8,#T_52ef7_row2_col9,#T_52ef7_row2_col10,#T_52ef7_row2_col11,#T_52ef7_row2_col12,#T_52ef7_row2_col13,#T_52ef7_row2_col14,#T_52ef7_row2_col15,#T_52ef7_row2_col16,#T_52ef7_row2_col17,#T_52ef7_row3_col0,#T_52ef7_row3_col1,#T_52ef7_row3_col2,#T_52ef7_row3_col3,#T_52ef7_row3_col4,#T_52ef7_row3_col5,#T_52ef7_row3_col6,#T_52ef7_row3_col7,#T_52ef7_row3_col8,#T_52ef7_row3_col9,#T_52ef7_row3_col10,#T_52ef7_row3_col11,#T_52ef7_row3_col12,#T_52ef7_row3_col13,#T_52ef7_row3_col14,#T_52ef7_row3_col15,#T_52ef7_row3_col16,#T_52ef7_row4_col0,#T_52ef7_row4_col1,#T_52ef7_row4_col2,#T_52ef7_row4_col3,#T_52ef7_row4_col4,#T_52ef7_row4_col5,#T_52ef7_row4_col6,#T_52ef7_row4_col7,#T_52ef7_row4_col8,#T_52ef7_row4_col9,#T_52ef7_row4_col10,#T_52ef7_row4_col11,#T_52ef7_row4_col12,#T_52ef7_row4_col13,#T_52ef7_row4_col14,#T_52ef7_row4_col15,#T_52ef7_row5_col0,#T_52ef7_row5_col1,#T_52ef7_row5_col2,#T_52ef7_row5_col3,#T_52ef7_row5_col4,#T_52ef7_row5_col5,#T_52ef7_row5_col6,#T_52ef7_row5_col7,#T_52ef7_row5_col8,#T_52ef7_row5_col9,#T_52ef7_row5_col10,#T_52ef7_row5_col11,#T_52ef7_row5_col12,#T_52ef7_row5_col13,#T_52ef7_row5_col14,#T_52ef7_row6_col0,#T_52ef7_row6_col1,#T_52ef7_row6_col2,#T_52ef7_row6_col3,#T_52ef7_row6_col4,#T_52ef7_row6_col5,#T_52ef7_row6_col6,#T_52ef7_row6_col7,#T_52ef7_row6_col8,#T_52ef7_row6_col9,#T_52ef7_row6_col10,#T_52ef7_row6_col11,#T_52ef7_row6_col12,#T_52ef7_row6_col13,#T_52ef7_row7_col0,#T_52ef7_row7_col1,#T_52ef7_row7_col2,#T_52ef7_row7_col3,#T_52ef7_row7_col4,#T_52ef7_row7_col5,#T_52ef7_row7_col6,#T_52ef7_row7_col7,#T_52ef7_row7_col8,#T_52ef7_row7_col9,#T_52ef7_row7_col10,#T_52ef7_row7_col11,#T_52ef7_row7_col12,#T_52ef7_row8_col0,#T_52ef7_row8_col1,#T_52ef7_row8_col2,#T_52ef7_row8_col3,#T_52ef7_row8_col4,#T_52ef7_row8_col5,#T_52ef7_row8_col6,#T_52ef7_row8_col7,#T_52ef7_row8_col8,#T_52ef7_row8_col9,#T_52ef7_row8_col10,#T_52ef7_row8_col11,#T_52ef7_row9_col0,#T_52ef7_row9_col1,#T_52ef7_row9_col2,#T_52ef7_row9_col3,#T_52ef7_row9_col4,#T_52ef7_row9_col5,#T_52ef7_row9_col6,#T_52ef7_row9_col7,#T_52ef7_row9_col8,#T_52ef7_row9_col9,#T_52ef7_row9_col10,#T_52ef7_row10_col0,#T_52ef7_row10_col1,#T_52ef7_row10_col2,#T_52ef7_row10_col3,#T_52ef7_row10_col4,#T_52ef7_row10_col5,#T_52ef7_row10_col6,#T_52ef7_row10_col7,#T_52ef7_row10_col8,#T_52ef7_row10_col9,#T_52ef7_row11_col0,#T_52ef7_row11_col1,#T_52ef7_row11_col2,#T_52ef7_row11_col3,#T_52ef7_row11_col4,#T_52ef7_row11_col5,#T_52ef7_row11_col6,#T_52ef7_row11_col7,#T_52ef7_row11_col8,#T_52ef7_row12_col0,#T_52ef7_row12_col1,#T_52ef7_row12_col2,#T_52ef7_row12_col3,#T_52ef7_row12_col4,#T_52ef7_row12_col5,#T_52ef7_row12_col6,#T_52ef7_row12_col7,#T_52ef7_row13_col0,#T_52ef7_row13_col1,#T_52ef7_row13_col2,#T_52ef7_row13_col3,#T_52ef7_row13_col4,#T_52ef7_row13_col5,#T_52ef7_row13_col6,#T_52ef7_row14_col0,#T_52ef7_row14_col1,#T_52ef7_row14_col2,#T_52ef7_row14_col3,#T_52ef7_row14_col4,#T_52ef7_row14_col5,#T_52ef7_row15_col0,#T_52ef7_row15_col1,#T_52ef7_row15_col2,#T_52ef7_row15_col3,#T_52ef7_row15_col4,#T_52ef7_row16_col0,#T_52ef7_row16_col1,#T_52ef7_row16_col2,#T_52ef7_row16_col3,#T_52ef7_row17_ ...
#             color:  lightgray;
#         }#T_52ef7_row0_col20,#T_52ef7_row1_col19,#T_52ef7_row1_col20,#T_52ef7_row2_col18,#T_52ef7_row2_col19,#T_52ef7_row2_col20,#T_52ef7_row3_col17,#T_52ef7_row3_col18,#T_52ef7_row3_col19,#T_52ef7_row3_col20,#T_52ef7_row4_col16,#T_52ef7_row4_col17,#T_52ef7_row4_col18,#T_52ef7_row4_col19,#T_52ef7_row4_col20,#T_52ef7_row5_col15,#T_52ef7_row5_col16,#T_52ef7_row5_col17,#T_52ef7_row5_col18,#T_52ef7_row5_col19,#T_52ef7_row5_col20,#T_52ef7_row6_col14,#T_52ef7_row6_col15,#T_52ef7_row6_col16,#T_52ef7_row6_col17,#T_52ef7_row6_col18,#T_52ef7_row6_col19,#T_52ef7_row6_col20,#T_52ef7_row7_col13,#T_52ef7_row7_col14,#T_52ef7_row7_col15,#T_52ef7_row7_col16,#T_52ef7_row7_col17,#T_52ef7_row7_col18,#T_52ef7_row7_col19,#T_52ef7_row7_col20,#T_52ef7_row8_col12,#T_52ef7_row8_col13,#T_52ef7_row8_col14,#T_52ef7_row8_col15,#T_52ef7_row8_col16,#T_52ef7_row8_col17,#T_52ef7_row8_col18,#T_52ef7_row8_col19,#T_52ef7_row8_col20,#T_52ef7_row9_col11,#T_52ef7_row9_col12,#T_52ef7_row9_col13,#T_52ef7_row9_col14,#T_52ef7_row9_col15,#T_52ef7_row9_col16,#T_52ef7_row9_col17,#T_52ef7_row9_col18,#T_52ef7_row9_col19,#T_52ef7_row9_col20,#T_52ef7_row10_col10,#T_52ef7_row10_col11,#T_52ef7_row10_col12,#T_52ef7_row10_col13,#T_52ef7_row10_col14,#T_52ef7_row10_col15,#T_52ef7_row10_col16,#T_52ef7_row10_col17,#T_52ef7_row10_col18,#T_52ef7_row10_col19,#T_52ef7_row10_col20,#T_52ef7_row11_col9,#T_52ef7_row11_col10,#T_52ef7_row11_col11,#T_52ef7_row11_col12,#T_52ef7_row11_col13,#T_52ef7_row11_col14,#T_52ef7_row11_col15,#T_52ef7_row11_col16,#T_52ef7_row11_col17,#T_52ef7_row11_col18,#T_52ef7_row11_col19,#T_52ef7_row11_col20,#T_52ef7_row12_col8,#T_52ef7_row12_col9,#T_52ef7_row12_col10,#T_52ef7_row12_col11,#T_52ef7_row12_col12,#T_52ef7_row12_col13,#T_52ef7_row12_col14,#T_52ef7_row12_col15,#T_52ef7_row12_col16,#T_52ef7_row12_col17,#T_52ef7_row12_col18,#T_52ef7_row12_col19,#T_52ef7_row12_col20,#T_52ef7_row13_col7,#T_52ef7_row13_col8,#T_52ef7_row13_col9,#T_52ef7_row13_col10,#T_52ef7_row13_col11,#T_52ef7_row13_col12,#T_52ef7_row13_col13,#T_52ef7_row13_col14,#T_52ef7_row13_col15,#T_52ef7_row13_col16,#T_52ef7_row13_col17,#T_52ef7_row13_col18,#T_52ef7_row13_col19,#T_52ef7_row13_col20,#T_52ef7_row14_col6,#T_52ef7_row14_col7,#T_52ef7_row14_col8,#T_52ef7_row14_col9,#T_52ef7_row14_col10,#T_52ef7_row14_col11,#T_52ef7_row14_col12,#T_52ef7_row14_col13,#T_52ef7_row14_col14,#T_52ef7_row14_col15,#T_52ef7_row14_col16,#T_52ef7_row14_col17,#T_52ef7_row14_col18,#T_52ef7_row14_col19,#T_52ef7_row14_col20,#T_52ef7_row15_col5,#T_52ef7_row15_col6,#T_52ef7_row15_col7,#T_52ef7_row15_col8,#T_52ef7_row15_col9,#T_52ef7_row15_col10,#T_52ef7_row15_col11,#T_52ef7_row15_col12,#T_52ef7_row15_col13,#T_52ef7_row15_col14,#T_52ef7_row15_col15,#T_52ef7_row15_col16,#T_52ef7_row15_col17,#T_52ef7_row15_col18,#T_52ef7_row15_col19,#T_52ef7_row15_col20,#T_52ef7_row16_col4,#T_52ef7_row16_col5,#T_52ef7_row16_col6,#T_52ef7_row16_col7,#T_52ef7_row16_col8,#T_52ef7_row16_col9,#T_52ef7_row16_col10,#T_52ef7_row16_col11,#T_52ef7_row16_col12,#T_52ef7_row16_col13,#T_52ef7_row16_col14,#T_52ef7_row16_col15,#T_52ef7_row16_col16,#T_52ef7_row16_col17,#T_52ef7_row16_col18,#T_52ef7_row16_col19,#T_52ef7_row16_col20,#T_52ef7_row17_col3,#T_52ef7_row17_col4,#T_52ef7_row17_col5,#T_52ef7_row17_col6,#T_52ef7_row17_col7,#T_52ef7_row17_col8,#T_52ef7_row17_col9,#T_52ef7_row17_col10,#T_52ef7_row17_col11,#T

# %% [markdown]
# ## Meaning
#
# The Pascal's Triangle indicates:
#
#  - the number of combinations of $n$ elements, $k$ by $k$ ($n$ chose $k$);
#
#  - the number of possible paths to reach node $(n,k)$, starting from the root node in a binary tree;
#
#  - at each row, the coefficients of the developped power of the sum of two terms (binomial coefficients): $(a + b)^n = \sum^n_{k=0} \binom{n}{k} a^{n-k} b^{k}$;
#
#  - at each row, divided by its sum $2^n$, the binomial distribution in the symmetric case where $p = 1/2$.
#
#
# See: https://www.johndcook.com/blog/binomial_coefficients/
#
# See: https://en.wikipedia.org/wiki/Binomial_coefficient
#
# See: https://fr.wikipedia.org/wiki/Triangle_de_Pascal
#
# See: https://mathworld.wolfram.com/PascalsTriangle.html
#
# See: https://www.cut-the-knot.org/arithmetic/combinatorics/BinomialTheorem.shtml
#
# See: https://www.mathsisfun.com/pascals-triangle.html
#
# See: https://www.math10.com/en/algebra/probabilities/binomial-theorem/binomial-theorem.html
#
#
# ## Main Properties
#
# The Pascal triangle ensure the folowing properties:
#
# $ \binom{n}{k} = 0 $  when  $k>n$.
#
# $ \binom{n}{k} = 1 $  when  $k=0$ or $k=n$.
#
# $ \binom{n}{k} = \binom{n-1}{k-1} + \binom{n-1}{k} \ , \ \forall n, k > 0$
#
# ## Gambling Context
#
# It is the base of combinatorics, and can be seen, in the gambling context, as the number of ways a gambler can observe $k$ successes after playing $n$ rounds.
#
# ## Sum of a row in Pascal's Triangle
#
# The sum of all possible paths in a given level is the sum of all terms of the binomial coefficient for a given number of rounds $t$, i.e. considering sequences of "success or failure", the number of possible sequences:
#
# $ \sum\limits_{k=0}^n \binom{n}{k} \ = \ 2^n$
